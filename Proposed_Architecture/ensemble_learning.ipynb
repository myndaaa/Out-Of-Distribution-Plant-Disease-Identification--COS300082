# %% [markdown]
# # Data processing and loading

# %%
# Importing required libraries
import pandas as pd
import os

# Define the directories for plantvillage and plantdoc
base_dir = r'C:\Users\bheja\OneDrive\Desktop\Dataset'
plant_vil_dir = os.path.join(base_dir, 'plantvillage')
plant_doc_dir = os.path.join(base_dir, 'plantdoc')

# Load the CSV files
train_csv_path = os.path.join(base_dir, 'PV_train.csv')
test_seen_csv_path = os.path.join(base_dir, 'PV_test_seen.csv')
test_unseen_csv_path = os.path.join(base_dir, 'PV_test_unseen.csv')
doc_unseen_csv_path = os.path.join(base_dir, 'PD_test_unseen.csv')

# Read the CSV files into pandas DataFrames
train_data = pd.read_csv(train_csv_path, header=None, names=["image_name", "crop_class", "disease_class"])
test_seen_data = pd.read_csv(test_seen_csv_path, header=None, names=["image_name", "crop_class", "disease_class"])
test_unseen_data = pd.read_csv(test_unseen_csv_path, header=None, names=["image_name", "crop_class", "disease_class"])
doc_unseen_data = pd.read_csv(doc_unseen_csv_path, header=None, names=["image_name", "crop_class", "disease_class"])

# %%
# Print the data types of the columns in the DataFrame
print("Data types of columns in train_data:")
print(train_data.dtypes)

# Print the data types for the specific columns (crop_class and disease_class)
print("\nData type of 'crop_class' column:", train_data["crop_class"].dtype)
print("Data type of 'disease_class' column:", train_data["disease_class"].dtype)
# Out:
# Data types of columns in train_data:
# image_name       object
# crop_class        int64
# disease_class     int64
# dtype: object
#
# Data type of 'crop_class' column: int64
# Data type of 'disease_class' column: int64

# %% [markdown]
# # Crop Class

# %% [markdown]
# ## Balancing the dataset

# %%
# Dataset Balancing for Crop Classes

from sklearn.utils.class_weight import compute_class_weight
import numpy as np

# Extract the crop class labels from the training data
y_crop = train_data['crop_class'].astype(str).values  # Convert to string since class_weight requires classes as strings or integers

# Calculate class weights for the crop classes
crop_classes = np.unique(y_crop)  # Get unique crop classes
class_weights_crop = compute_class_weight('balanced', classes=crop_classes, y=y_crop)
class_weights_crop_dict = dict(zip(crop_classes, class_weights_crop))

# Print the class weights for crop classes
print("Class Weights for Crop Classes:")
print(class_weights_crop_dict)
# Out:
# Class Weights for Crop Classes:
# {'0': 1.2648890618917867, '1': 2.785285714285714, '10': 2.785285714285714, '11': 1.8531508411747932, '12': 2.1116646810354163, '13': 0.19303387028108077, '2': 1.6870295059271436, '3': 0.8999307639049158, '4': 0.8836566352429297, '5': 0.6386805123333442, '6': 1.326958415572041, '7': 2.198331266208141, '8': 1.6307293409166945, '9': 13.390796703296703}

# %% [markdown]
# ## Image Preprocessing

# %%
pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\bheja\.conda\envs\mysha\lib\site-packages (from opencv-python) (1.23.5)
# Downloading opencv_python-4.10.0.84-cp37-abi3-win_amd64.whl (38.8 MB)
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---- ----------------------------------- 3.9/38.8 MB 23.5 MB/s eta 0:00:02
#    ----------- ---------------------------- 11.5/38.8 MB 31.4 MB/s eta 0:00:01
#    -------------------- ------------------- 19.9/38.8 MB 34.0 MB/s eta 0:00:01
#    ---------------------------- ----------- 27.8/38.8 MB 35.2 MB/s eta 0:00:01
#    ------------------------------------ --- 35.7/38.8 MB 36.0 MB/s eta 0:00:01
#    ---------------------------------------- 38.8/38.8 MB 34.3 MB/s eta 0:00:00
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.10.0.84
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import numpy as np
import os

# Function for image pre-processing
def preprocess_image(image_path):
    # Read the image in RGB format
    image = cv2.imread(image_path)
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    
    # Convert the image from RGB to Lab color space
    image_lab = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2Lab)
    
    # Apply CLAHE to the L channel
    l_channel, a_channel, b_channel = cv2.split(image_lab)
    clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8, 8))
    l_channel = clahe.apply(l_channel)
    
    # Merge the L, a, b channels and convert back to RGB color space
    image_lab = cv2.merge((l_channel, a_channel, b_channel))
    enhanced_image = cv2.cvtColor(image_lab, cv2.COLOR_Lab2RGB)
    
    # Apply Adaptive Median Filter to remove noise
    enhanced_image_filtered = cv2.medianBlur(enhanced_image, 3)
    
    return enhanced_image_filtered

# Test the preprocessing function on a sample image
sample_image_path = os.path.join(plant_vil_dir, train_data.iloc[0]['image_name'])
processed_image = preprocess_image(sample_image_path)

# Display the original and preprocessed images for comparison
import matplotlib.pyplot as plt

original_image = cv2.imread(sample_image_path)
original_image_rgb = cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.imshow(original_image_rgb)
plt.title('Original Image')

plt.subplot(1, 2, 2)
plt.imshow(processed_image)
plt.title('Preprocessed Image')

plt.show()

# %% [markdown]
# ## Generators

# %%
train_data["crop_class"] = train_data["crop_class"].astype(str)
test_seen_data["crop_class"] = test_seen_data["crop_class"].astype(str)
test_unseen_data["crop_class"] = test_unseen_data["crop_class"].astype(str)
doc_unseen_data["crop_class"] = doc_unseen_data["crop_class"].astype(str)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Create data augmentation generator for training
train_datagen_crop = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

# Create data generator for testing --without augmentation, only rescale--
test_datagen_crop = ImageDataGenerator(rescale=1./255)

# Create the training data generator
train_generator_crop = train_datagen_crop.flow_from_dataframe(
    dataframe=train_data,
    directory=plant_vil_dir,
    x_col="image_name",
    y_col="crop_class",
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=True
)

# Use the class indices from the training generator
classes_list = list(train_generator_crop.class_indices.keys())

# Use the same classes_list to ensure consistency in the testing generators
test_seen_generator_crop = test_datagen_crop.flow_from_dataframe(
    dataframe=test_seen_data,
    directory=plant_vil_dir,
    x_col="image_name",
    y_col="crop_class",
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    classes=classes_list,  # Using the same classes as training generator
    shuffle=False
)

test_unseen_generator_crop = test_datagen_crop.flow_from_dataframe(
    dataframe=test_unseen_data,
    directory=plant_vil_dir,
    x_col="image_name",
    y_col="crop_class",
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    classes=classes_list,  # Using the same classes as training generator
    shuffle=False
)

doc_unseen_generator_crop = test_datagen_crop.flow_from_dataframe(
    dataframe=doc_unseen_data,
    directory=plant_doc_dir,
    x_col="image_name",
    y_col="crop_class",
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    classes=classes_list,  # Using the same classes as training generator
    shuffle=False
)

# Verify the class indices for the data generators again -- :) I guess good practice
print("Class indices for training generator (Crop):", train_generator_crop.class_indices)
print("Class indices for testing generator (Seen Crop):", test_seen_generator_crop.class_indices)
print("Class indices for testing generator (Unseen Crop):", test_unseen_generator_crop.class_indices)
print("Class indices for testing generator (Doc Unseen Crop):", doc_unseen_generator_crop.class_indices)
# Out:
# Found 38994 validated image filenames belonging to 14 classes.
# Found 10279 validated image filenames belonging to 14 classes.
# Found 216 validated image filenames belonging to 14 classes.
# Found 71 validated image filenames belonging to 14 classes.
# Class indices for training generator (Crop): {'0': 0, '1': 1, '10': 2, '11': 3, '12': 4, '13': 5, '2': 6, '3': 7, '4': 8, '5': 9, '6': 10, '7': 11, '8': 12, '9': 13}
# Class indices for testing generator (Seen Crop): {'0': 0, '1': 1, '10': 2, '11': 3, '12': 4, '13': 5, '2': 6, '3': 7, '4': 8, '5': 9, '6': 10, '7': 11, '8': 12, '9': 13}
# Class indices for testing generator (Unseen Crop): {'0': 0, '1': 1, '10': 2, '11': 3, '12': 4, '13': 5, '2': 6, '3': 7, '4': 8, '5': 9, '6': 10, '7': 11, '8': 12, '9': 13}
# Class indices for testing generator (Doc Unseen Crop): {'0': 0, '1': 1, '10': 2, '11': 3, '12': 4, '13': 5, '2': 6, '3': 7, '4': 8, '5': 9, '6': 10, '7': 11, '8': 12, '9': 13}

# %% [markdown]
# ## Training

# %%
# Convert keys of class_weights_crop_dict to integers
class_weights_crop_dict = {int(k): v for k, v in class_weights_crop_dict.items()}

# Print the updated class weights for crop classes
print("Updated Class Weights for Crop Classes:")
print(class_weights_crop_dict)
# Out:
# Updated Class Weights for Crop Classes:
# {0: 1.2648890618917867, 1: 2.785285714285714, 10: 2.785285714285714, 11: 1.8531508411747932, 12: 2.1116646810354163, 13: 0.19303387028108077, 2: 1.6870295059271436, 3: 0.8999307639049158, 4: 0.8836566352429297, 5: 0.6386805123333442, 6: 1.326958415572041, 7: 2.198331266208141, 8: 1.6307293409166945, 9: 13.390796703296703}

# %% [markdown]
# ### Resnet50v2

# %%
from tensorflow.keras.applications import ResNet50V2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from tensorflow.keras.metrics import Precision, Recall, AUC
import numpy as np

# Load pre-trained ResNet50V2 model + higher level layers
# We're using the 'imagenet' weights and excluding the top layers
base_model = ResNet50V2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the initial layers to retain the pre-trained features
for layer in base_model.layers[:100]:
    layer.trainable = False

# Add custom layers on top
x = base_model.output
x = GlobalAveragePooling2D()(x)  # Reduce spatial dimensions
x = Dense(1024, activation='relu')(x)  # Fully connected layer
x = Dropout(0.4)(x)  # Add Dropout to prevent overfitting
x = Dense(512, activation='relu')(x)  # Fully connected layer
x = Dropout(0.4)(x)  # Add Dropout to prevent overfitting
x = Dense(256, activation='relu')(x)  # Fully connected layer
x = Dropout(0.4)(x)  # Add Dropout to prevent overfitting
output = Dense(len(classes_list), activation='softmax')(x)  # Output layer with number of crop classes

# Define the model
model = Model(inputs=base_model.input, outputs=output)

# Compile the model with a higher learning rate
model.compile(optimizer=Adam(learning_rate=1e-3),
              loss='categorical_crossentropy',
              metrics=['accuracy', Precision(), Recall(), AUC()])

# Define callbacks for training
checkpoint_resnet = ModelCheckpoint(filepath=r'C:\Users\bheja\OneDrive\Desktop\models\resnet50v2_crop.h5',
                                    monitor='val_loss',
                                    save_best_only=True,
                                    save_weights_only=False,
                                    verbose=1)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',          # Monitor validation loss to decide when to reduce the learning rate
    factor=0.5,                  # Reduce learning rate by a factor of 0.5
    patience=3,                  # Number of epochs with no improvement after which learning rate will be reduced
    min_lr=1e-7,                 # Lower bound on the learning rate to prevent it from going too low
    verbose=1                    # Prints a message when learning rate is reduced
)

early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model using the training and validation generators
history_resnet = model.fit(
    train_generator_crop,
    epochs=50,  # Training with transfer learning so not going for 100 as the earliar models
    batch_size=32,
    validation_data=test_seen_generator_crop,
    class_weight=class_weights_crop_dict,  # Use class weights for imbalance
    callbacks=[reduce_lr, early_stop, checkpoint_resnet]
)
# Out:
# Epoch 1/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.9984 - accuracy: 0.7934 - precision_2: 0.8903 - recall_2: 0.7279 - auc_2: 0.9738
# Epoch 1: val_loss improved from inf to 0.17002, saving model to C:\Users\bheja\OneDrive\Desktop\models\resnet50v2_crop.h5
# 1219/1219 [==============================] - 950s 767ms/step - loss: 0.9984 - accuracy: 0.7934 - precision_2: 0.8903 - recall_2: 0.7279 - auc_2: 0.9738 - val_loss: 0.1700 - val_accuracy: 0.9552 - val_precision_2: 0.9637 - val_recall_2: 0.9498 - val_auc_2: 0.9963 - lr: 0.0010
# Epoch 2/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.2970 - accuracy: 0.9356 - precision_2: 0.9526 - recall_2: 0.9194 - auc_2: 0.9942
# Epoch 2: val_loss did not improve from 0.17002
# 1219/1219 [==============================] - 863s 708ms/step - loss: 0.2970 - accuracy: 0.9356 - precision_2: 0.9526 - recall_2: 0.9194 - auc_2: 0.9942 - val_loss: 0.2745 - val_accuracy: 0.9302 - val_precision_2: 0.9414 - val_recall_2: 0.9226 - val_auc_2: 0.9913 - lr: 0.0010
# Epoch 3/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.2780 - accuracy: 0.9446 - precision_2: 0.9588 - recall_2: 0.9297 - auc_2: 0.9948
# Epoch 3: val_loss did not improve from 0.17002
# 1219/1219 [==============================] - 911s 747ms/step - loss: 0.2780 - accuracy: 0.9446 - precision_2: 0.9588 - recall_2: 0.9297 - auc_2: 0.9948 - val_loss: 0.3139 - val_accuracy: 0.9235 - val_precision_2: 0.9333 - val_recall_2: 0.9193 - val_auc_2: 0.9899 - lr: 0.0010
# Epoch 4/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.2209 - accuracy: 0.9548 - precision_2: 0.9646 - recall_2: 0.9434 - auc_2: 0.9956
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 4: val_loss did not improve from 0.17002
# 1219/1219 [==============================] - 590s 484ms/step - loss: 0.2209 - accuracy: 0.9548 - precision_2: 0.9646 - recall_2: 0.9434 - auc_2: 0.9956 - val_loss: 0.2291 - val_accuracy: 0.9515 - val_precision_2: 0.9594 - val_recall_2: 0.9449 - val_auc_2: 0.9917 - lr: 0.0010
# Epoch 5/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0902 - accuracy: 0.9779 - precision_2: 0.9824 - recall_2: 0.9726 - auc_2: 0.9983
# Epoch 5: val_loss improved from 0.17002 to 0.05454, saving model to C:\Users\bheja\OneDrive\Desktop\models\resnet50v2_crop.h5
# 1219/1219 [==============================] - 513s 421ms/step - loss: 0.0902 - accuracy: 0.9779 - precision_2: 0.9824 - recall_2: 0.9726 - auc_2: 0.9983 - val_loss: 0.0545 - val_accuracy: 0.9850 - val_precision_2: 0.9877 - val_recall_2: 0.9831 - val_auc_2: 0.9990 - lr: 5.0000e-04
# Epoch 6/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0770 - accuracy: 0.9809 - precision_2: 0.9844 - recall_2: 0.9778 - auc_2: 0.9987
# Epoch 6: val_loss did not improve from 0.05454
# 1219/1219 [==============================] - 514s 421ms/step - loss: 0.0770 - accuracy: 0.9809 - precision_2: 0.9844 - recall_2: 0.9778 - auc_2: 0.9987 - val_loss: 0.0773 - val_accuracy: 0.9807 - val_precision_2: 0.9842 - val_recall_2: 0.9788 - val_auc_2: 0.9978 - lr: 5.0000e-04
# Epoch 7/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0805 - accuracy: 0.9822 - precision_2: 0.9854 - recall_2: 0.9792 - auc_2: 0.9985
# Epoch 7: val_loss did not improve from 0.05454
# 1219/1219 [==============================] - 519s 426ms/step - loss: 0.0805 - accuracy: 0.9822 - precision_2: 0.9854 - recall_2: 0.9792 - auc_2: 0.9985 - val_loss: 0.1051 - val_accuracy: 0.9791 - val_precision_2: 0.9805 - val_recall_2: 0.9769 - val_auc_2: 0.9968 - lr: 5.0000e-04
# Epoch 8/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0723 - accuracy: 0.9825 - precision_2: 0.9854 - recall_2: 0.9795 - auc_2: 0.9986
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 8: val_loss improved from 0.05454 to 0.05450, saving model to C:\Users\bheja\OneDrive\Desktop\models\resnet50v2_crop.h5
# 1219/1219 [==============================] - 726s 596ms/step - loss: 0.0723 - accuracy: 0.9825 - precision_2: 0.9854 - recall_2: 0.9795 - auc_2: 0.9986 - val_loss: 0.0545 - val_accuracy: 0.9845 - val_precision_2: 0.9860 - val_recall_2: 0.9831 - val_auc_2: 0.9988 - lr: 5.0000e-04
# Epoch 9/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0418 - accuracy: 0.9900 - precision_2: 0.9915 - recall_2: 0.9885 - auc_2: 0.9993
# Epoch 9: val_loss improved from 0.05450 to 0.03631, saving model to C:\Users\bheja\OneDrive\Desktop\models\resnet50v2_crop.h5
# 1219/1219 [==============================] - 723s 593ms/step - loss: 0.0418 - accuracy: 0.9900 - precision_2: 0.9915 - recall_2: 0.9885 - auc_2: 0.9993 - val_loss: 0.0363 - val_accuracy: 0.9905 - val_precision_2: 0.9916 - val_recall_2: 0.9894 - val_auc_2: 0.9993 - lr: 2.5000e-04
# Epoch 10/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0255 - accuracy: 0.9925 - precision_2: 0.9934 - recall_2: 0.9917 - auc_2: 0.9996
# Epoch 10: val_loss improved from 0.03631 to 0.03005, saving model to C:\Users\bheja\OneDrive\Desktop\models\resnet50v2_crop.h5
# 1219/1219 [==============================] - 541s 444ms/step - loss: 0.0255 - accuracy: 0.9925 - precision_2: 0.9934 - recall_2: 0.9917 - auc_2: 0.9996 - val_loss: 0.0301 - val_accuracy: 0.9931 - val_precision_2: 0.9937 - val_recall_2: 0.9925 - val_auc_2: 0.9994 - lr: 2.5000e-04
# Epoch 11/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0313 - accuracy: 0.9926 - precision_2: 0.9936 - recall_2: 0.9916 - auc_2: 0.9996
# Epoch 11: val_loss did not improve from 0.03005
# 1219/1219 [==============================] - 509s 417ms/step - loss: 0.0313 - accuracy: 0.9926 - precision_2: 0.9936 - recall_2: 0.9916 - auc_2: 0.9996 - val_loss: 0.0438 - val_accuracy: 0.9902 - val_precision_2: 0.9911 - val_recall_2: 0.9893 - val_auc_2: 0.9987 - lr: 2.5000e-04
# Epoch 12/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0305 - accuracy: 0.9929 - precision_2: 0.9937 - recall_2: 0.9918 - auc_2: 0.9994
# Epoch 12: val_loss did not improve from 0.03005
# 1219/1219 [==============================] - 821s 674ms/step - loss: 0.0305 - accuracy: 0.9929 - precision_2: 0.9937 - recall_2: 0.9918 - auc_2: 0.9994 - val_loss: 0.0381 - val_accuracy: 0.9921 - val_precision_2: 0.9928 - val_recall_2: 0.9916 - val_auc_2: 0.9989 - lr: 2.5000e-04
# Epoch 13/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0247 - accuracy: 0.9939 - precision_2: 0.9946 - recall_2: 0.9933 - auc_2: 0.9996
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 13: val_loss did not improve from 0.03005
# 1219/1219 [==============================] - 574s 470ms/step - loss: 0.0247 - accuracy: 0.9939 - precision_2: 0.9946 - recall_2: 0.9933 - auc_2: 0.9996 - val_loss: 0.0513 - val_accuracy: 0.9910 - val_precision_2: 0.9921 - val_recall_2: 0.9906 - val_auc_2: 0.9985 - lr: 2.5000e-04
# Epoch 14/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0165 - accuracy: 0.9955 - precision_2: 0.9960 - recall_2: 0.9949 - auc_2: 0.9996
# Epoch 14: val_loss did not improve from 0.03005
# 1219/1219 [==============================] - 517s 424ms/step - loss: 0.0165 - accuracy: 0.9955 - precision_2: 0.9960 - recall_2: 0.9949 - auc_2: 0.9996 - val_loss: 0.0326 - val_accuracy: 0.9934 - val_precision_2: 0.9940 - val_recall_2: 0.9931 - val_auc_2: 0.9990 - lr: 1.2500e-04
# Epoch 15/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0149 - accuracy: 0.9953 - precision_2: 0.9958 - recall_2: 0.9950 - auc_2: 0.9998
# Epoch 15: val_loss did not improve from 0.03005
# 1219/1219 [==============================] - 533s 437ms/step - loss: 0.0149 - accuracy: 0.9953 - precision_2: 0.9958 - recall_2: 0.9950 - auc_2: 0.9998 - val_loss: 0.0303 - val_accuracy: 0.9937 - val_precision_2: 0.9941 - val_recall_2: 0.9933 - val_auc_2: 0.9991 - lr: 1.2500e-04
# Epoch 16/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0110 - accuracy: 0.9966 - precision_2: 0.9969 - recall_2: 0.9965 - auc_2: 0.9998
# Epoch 16: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 16: val_loss did not improve from 0.03005
# 1219/1219 [==============================] - 510s 419ms/step - loss: 0.0110 - accuracy: 0.9966 - precision_2: 0.9969 - recall_2: 0.9965 - auc_2: 0.9998 - val_loss: 0.0303 - val_accuracy: 0.9937 - val_precision_2: 0.9942 - val_recall_2: 0.9936 - val_auc_2: 0.9990 - lr: 1.2500e-04
# Epoch 17/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0095 - accuracy: 0.9974 - precision_2: 0.9976 - recall_2: 0.9972 - auc_2: 0.9998
# Epoch 17: val_loss did not improve from 0.03005
# 1219/1219 [==============================] - 523s 429ms/step - loss: 0.0095 - accuracy: 0.9974 - precision_2: 0.9976 - recall_2: 0.9972 - auc_2: 0.9998 - val_loss: 0.0342 - val_accuracy: 0.9924 - val_precision_2: 0.9929 - val_recall_2: 0.9924 - val_auc_2: 0.9989 - lr: 6.2500e-05
# Epoch 18/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0074 - accuracy: 0.9974 - precision_2: 0.9976 - recall_2: 0.9972 - auc_2: 0.9999
# Epoch 18: val_loss did not improve from 0.03005
# 1219/1219 [==============================] - 531s 436ms/step - loss: 0.0074 - accuracy: 0.9974 - precision_2: 0.9976 - recall_2: 0.9972 - auc_2: 0.9999 - val_loss: 0.0306 - val_accuracy: 0.9938 - val_precision_2: 0.9941 - val_recall_2: 0.9937 - val_auc_2: 0.9990 - lr: 6.2500e-05
# Epoch 19/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0063 - accuracy: 0.9981 - precision_2: 0.9984 - recall_2: 0.9980 - auc_2: 0.9999
# Epoch 19: val_loss improved from 0.03005 to 0.02973, saving model to C:\Users\bheja\OneDrive\Desktop\models\resnet50v2_crop.h5
# 1219/1219 [==============================] - 599s 491ms/step - loss: 0.0063 - accuracy: 0.9981 - precision_2: 0.9984 - recall_2: 0.9980 - auc_2: 0.9999 - val_loss: 0.0297 - val_accuracy: 0.9948 - val_precision_2: 0.9949 - val_recall_2: 0.9946 - val_auc_2: 0.9989 - lr: 6.2500e-05
# Epoch 20/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0082 - accuracy: 0.9980 - precision_2: 0.9980 - recall_2: 0.9978 - auc_2: 0.9998
# Epoch 20: val_loss did not improve from 0.02973
# 1219/1219 [==============================] - 885s 726ms/step - loss: 0.0082 - accuracy: 0.9980 - precision_2: 0.9980 - recall_2: 0.9978 - auc_2: 0.9998 - val_loss: 0.0326 - val_accuracy: 0.9946 - val_precision_2: 0.9947 - val_recall_2: 0.9945 - val_auc_2: 0.9989 - lr: 6.2500e-05
# Epoch 21/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0051 - accuracy: 0.9984 - precision_2: 0.9985 - recall_2: 0.9983 - auc_2: 0.9999
# Epoch 21: val_loss did not improve from 0.02973
# 1219/1219 [==============================] - 718s 589ms/step - loss: 0.0051 - accuracy: 0.9984 - precision_2: 0.9985 - recall_2: 0.9983 - auc_2: 0.9999 - val_loss: 0.0374 - val_accuracy: 0.9947 - val_precision_2: 0.9949 - val_recall_2: 0.9945 - val_auc_2: 0.9985 - lr: 6.2500e-05
# Epoch 22/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0074 - accuracy: 0.9981 - precision_2: 0.9982 - recall_2: 0.9980 - auc_2: 0.9998
# Epoch 22: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 22: val_loss did not improve from 0.02973
# 1219/1219 [==============================] - 550s 451ms/step - loss: 0.0074 - accuracy: 0.9981 - precision_2: 0.9982 - recall_2: 0.9980 - auc_2: 0.9998 - val_loss: 0.0331 - val_accuracy: 0.9948 - val_precision_2: 0.9950 - val_recall_2: 0.9948 - val_auc_2: 0.9988 - lr: 6.2500e-05
# Epoch 23/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0043 - accuracy: 0.9986 - precision_2: 0.9988 - recall_2: 0.9986 - auc_2: 0.9999
# Epoch 23: val_loss did not improve from 0.02973
# 1219/1219 [==============================] - 524s 430ms/step - loss: 0.0043 - accuracy: 0.9986 - precision_2: 0.9988 - recall_2: 0.9986 - auc_2: 0.9999 - val_loss: 0.0327 - val_accuracy: 0.9949 - val_precision_2: 0.9953 - val_recall_2: 0.9949 - val_auc_2: 0.9988 - lr: 3.1250e-05
# Epoch 24/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 0.9986 - precision_2: 0.9988 - recall_2: 0.9986 - auc_2: 0.9999
# Epoch 24: val_loss did not improve from 0.02973
# 1219/1219 [==============================] - 528s 433ms/step - loss: 0.0046 - accuracy: 0.9986 - precision_2: 0.9988 - recall_2: 0.9986 - auc_2: 0.9999 - val_loss: 0.0313 - val_accuracy: 0.9951 - val_precision_2: 0.9952 - val_recall_2: 0.9949 - val_auc_2: 0.9990 - lr: 3.1250e-05
# Epoch 25/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0045 - accuracy: 0.9987 - precision_2: 0.9988 - recall_2: 0.9987 - auc_2: 0.9999
# Epoch 25: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 25: val_loss did not improve from 0.02973
# 1219/1219 [==============================] - 526s 431ms/step - loss: 0.0045 - accuracy: 0.9987 - precision_2: 0.9988 - recall_2: 0.9987 - auc_2: 0.9999 - val_loss: 0.0319 - val_accuracy: 0.9951 - val_precision_2: 0.9951 - val_recall_2: 0.9948 - val_auc_2: 0.9989 - lr: 3.1250e-05
# Epoch 26/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0036 - accuracy: 0.9989 - precision_2: 0.9989 - recall_2: 0.9988 - auc_2: 0.9999
# Epoch 26: val_loss did not improve from 0.02973
# 1219/1219 [==============================] - 524s 430ms/step - loss: 0.0036 - accuracy: 0.9989 - precision_2: 0.9989 - recall_2: 0.9988 - auc_2: 0.9999 - val_loss: 0.0347 - val_accuracy: 0.9946 - val_precision_2: 0.9947 - val_recall_2: 0.9946 - val_auc_2: 0.9987 - lr: 1.5625e-05
# Epoch 27/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 0.9991 - precision_2: 0.9991 - recall_2: 0.9990 - auc_2: 0.9999
# Epoch 27: val_loss did not improve from 0.02973
# 1219/1219 [==============================] - 529s 434ms/step - loss: 0.0038 - accuracy: 0.9991 - precision_2: 0.9991 - recall_2: 0.9990 - auc_2: 0.9999 - val_loss: 0.0342 - val_accuracy: 0.9949 - val_precision_2: 0.9949 - val_recall_2: 0.9948 - val_auc_2: 0.9988 - lr: 1.5625e-05
# Epoch 28/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9989 - precision_2: 0.9989 - recall_2: 0.9988 - auc_2: 0.9999
# Epoch 28: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
#
# Epoch 28: val_loss did not improve from 0.02973
# 1219/1219 [==============================] - 525s 430ms/step - loss: 0.0037 - accuracy: 0.9989 - precision_2: 0.9989 - recall_2: 0.9988 - auc_2: 0.9999 - val_loss: 0.0329 - val_accuracy: 0.9949 - val_precision_2: 0.9949 - val_recall_2: 0.9948 - val_auc_2: 0.9989 - lr: 1.5625e-05
# Epoch 29/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9989 - precision_2: 0.9990 - recall_2: 0.9989 - auc_2: 1.0000
# Epoch 29: val_loss did not improve from 0.02973
# 1219/1219 [==============================] - 529s 434ms/step - loss: 0.0027 - accuracy: 0.9989 - precision_2: 0.9990 - recall_2: 0.9989 - auc_2: 1.0000 - val_loss: 0.0340 - val_accuracy: 0.9950 - val_precision_2: 0.9951 - val_recall_2: 0.9948 - val_auc_2: 0.9988 - lr: 7.8125e-06

# %%
import matplotlib.pyplot as plt

# Plot Training vs Validation Loss
plt.figure(figsize=(12, 6))
plt.plot(history_resnet.history['loss'], label='Training Loss')
plt.plot(history_resnet.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training vs. Validation Loss')
plt.legend()
plt.grid()
plt.show()

# Plot Training vs Validation Accuracy
plt.figure(figsize=(12, 6))
plt.plot(history_resnet.history['accuracy'], label='Training Accuracy')
plt.plot(history_resnet.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training vs. Validation Accuracy')
plt.legend()
plt.grid()
plt.show()

# Plot Training vs Validation Precision
plt.figure(figsize=(12, 6))
plt.plot(history_resnet.history['precision_2'], label='Training Precision')
plt.plot(history_resnet.history['val_precision_2'], label='Validation Precision')
plt.xlabel('Epochs')
plt.ylabel('Precision')
plt.title('Training vs. Validation Precision')
plt.legend()
plt.grid()
plt.show()

# Plot Training vs Validation Recall
plt.figure(figsize=(12, 6))
plt.plot(history_resnet.history['recall_2'], label='Training Recall')
plt.plot(history_resnet.history['val_recall_2'], label='Validation Recall')
plt.xlabel('Epochs')
plt.ylabel('Recall')
plt.title('Training vs. Validation Recall')
plt.legend()
plt.grid()
plt.show()

# Plot Training vs Validation AUC
plt.figure(figsize=(12, 6))
plt.plot(history_resnet.history['auc_2'], label='Training AUC')
plt.plot(history_resnet.history['val_auc_2'], label='Validation AUC')
plt.xlabel('Epochs')
plt.ylabel('AUC')
plt.title('Training vs. Validation AUC')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### DenseNet121

# %%
from tensorflow.keras.applications import DenseNet121  # Use a smaller model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from tensorflow.keras.metrics import Precision, Recall, AUC

# Load DenseNet121 with pre-trained ImageNet weights (using a smaller model)
base_model = DenseNet121(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the initial layers to reduce memory usage
for layer in base_model.layers[:300]:  # Freeze more layers to reduce computational load
    layer.trainable = False

# Custom layers on top of DenseNet121
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.4)(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.4)(x)
output = Dense(len(classes_list), activation='softmax')(x)

# Define and compile the DenseNet121 model
densenet_model = Model(inputs=base_model.input, outputs=output)
densenet_model.compile(optimizer=Adam(learning_rate=1e-3),
                       loss='categorical_crossentropy',
                       metrics=['accuracy', Precision(), Recall(), AUC()])

# Callbacks for DenseNet121
checkpoint_densenet = ModelCheckpoint(filepath=r'C:\Users\bheja\OneDrive\Desktop\models\densenet121_crop.h5', monitor='val_loss', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-7, verbose=1)
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the DenseNet121 model with a reduced batch size
history_densenet = densenet_model.fit(
    train_generator_crop,
    epochs=50,
    validation_data=test_seen_generator_crop,
    #batch_size=8,  # Reduce the batch size if "Resource exhausted"
    class_weight=class_weights_crop_dict,
    callbacks=[reduce_lr, early_stop, checkpoint_densenet]
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 [==============================] - 3s 0us/step
# Epoch 1/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.3372 - accuracy: 0.9331 - precision_5: 0.9515 - recall_5: 0.9204 - auc_5: 0.9935
# Epoch 1: val_loss improved from inf to 0.10520, saving model to C:\Users\bheja\OneDrive\Desktop\models\densenet121_crop.h5
# 1219/1219 [==============================] - 1010s 820ms/step - loss: 0.3372 - accuracy: 0.9331 - precision_5: 0.9515 - recall_5: 0.9204 - auc_5: 0.9935 - val_loss: 0.1052 - val_accuracy: 0.9686 - val_precision_5: 0.9719 - val_recall_5: 0.9667 - val_auc_5: 0.9973 - lr: 0.0010
# Epoch 2/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.1204 - accuracy: 0.9748 - precision_5: 0.9791 - recall_5: 0.9701 - auc_5: 0.9976
# Epoch 2: val_loss improved from 0.10520 to 0.09056, saving model to C:\Users\bheja\OneDrive\Desktop\models\densenet121_crop.h5
# 1219/1219 [==============================] - 750s 615ms/step - loss: 0.1204 - accuracy: 0.9748 - precision_5: 0.9791 - recall_5: 0.9701 - auc_5: 0.9976 - val_loss: 0.0906 - val_accuracy: 0.9763 - val_precision_5: 0.9785 - val_recall_5: 0.9749 - val_auc_5: 0.9978 - lr: 0.0010
# Epoch 3/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.1642 - accuracy: 0.9732 - precision_5: 0.9771 - recall_5: 0.9685 - auc_5: 0.9970
# Epoch 3: val_loss improved from 0.09056 to 0.03670, saving model to C:\Users\bheja\OneDrive\Desktop\models\densenet121_crop.h5
# 1219/1219 [==============================] - 574s 471ms/step - loss: 0.1642 - accuracy: 0.9732 - precision_5: 0.9771 - recall_5: 0.9685 - auc_5: 0.9970 - val_loss: 0.0367 - val_accuracy: 0.9903 - val_precision_5: 0.9925 - val_recall_5: 0.9870 - val_auc_5: 0.9993 - lr: 0.0010
# Epoch 4/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0872 - accuracy: 0.9829 - precision_5: 0.9851 - recall_5: 0.9797 - auc_5: 0.9982
# Epoch 4: val_loss improved from 0.03670 to 0.02949, saving model to C:\Users\bheja\OneDrive\Desktop\models\densenet121_crop.h5
# 1219/1219 [==============================] - 579s 475ms/step - loss: 0.0872 - accuracy: 0.9829 - precision_5: 0.9851 - recall_5: 0.9797 - auc_5: 0.9982 - val_loss: 0.0295 - val_accuracy: 0.9926 - val_precision_5: 0.9940 - val_recall_5: 0.9909 - val_auc_5: 0.9995 - lr: 0.0010
# Epoch 5/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0691 - accuracy: 0.9855 - precision_5: 0.9876 - recall_5: 0.9828 - auc_5: 0.9985
# Epoch 5: val_loss did not improve from 0.02949
# 1219/1219 [==============================] - 565s 463ms/step - loss: 0.0691 - accuracy: 0.9855 - precision_5: 0.9876 - recall_5: 0.9828 - auc_5: 0.9985 - val_loss: 0.3066 - val_accuracy: 0.9458 - val_precision_5: 0.9484 - val_recall_5: 0.9438 - val_auc_5: 0.9890 - lr: 0.0010
# Epoch 6/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0932 - accuracy: 0.9848 - precision_5: 0.9868 - recall_5: 0.9828 - auc_5: 0.9983
# Epoch 6: val_loss did not improve from 0.02949
# 1219/1219 [==============================] - 572s 469ms/step - loss: 0.0932 - accuracy: 0.9848 - precision_5: 0.9868 - recall_5: 0.9828 - auc_5: 0.9983 - val_loss: 0.0420 - val_accuracy: 0.9900 - val_precision_5: 0.9915 - val_recall_5: 0.9875 - val_auc_5: 0.9990 - lr: 0.0010
# Epoch 7/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0540 - accuracy: 0.9894 - precision_5: 0.9907 - recall_5: 0.9874 - auc_5: 0.9989
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 7: val_loss did not improve from 0.02949
# 1219/1219 [==============================] - 567s 465ms/step - loss: 0.0540 - accuracy: 0.9894 - precision_5: 0.9907 - recall_5: 0.9874 - auc_5: 0.9989 - val_loss: 0.0705 - val_accuracy: 0.9818 - val_precision_5: 0.9843 - val_recall_5: 0.9791 - val_auc_5: 0.9982 - lr: 0.0010
# Epoch 8/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0241 - accuracy: 0.9939 - precision_5: 0.9946 - recall_5: 0.9929 - auc_5: 0.9994
# Epoch 8: val_loss did not improve from 0.02949
# 1219/1219 [==============================] - 565s 463ms/step - loss: 0.0241 - accuracy: 0.9939 - precision_5: 0.9946 - recall_5: 0.9929 - auc_5: 0.9994 - val_loss: 0.0451 - val_accuracy: 0.9913 - val_precision_5: 0.9924 - val_recall_5: 0.9897 - val_auc_5: 0.9990 - lr: 5.0000e-04
# Epoch 9/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0192 - accuracy: 0.9951 - precision_5: 0.9955 - recall_5: 0.9947 - auc_5: 0.9995
# Epoch 9: val_loss improved from 0.02949 to 0.02276, saving model to C:\Users\bheja\OneDrive\Desktop\models\densenet121_crop.h5
# 1219/1219 [==============================] - 563s 462ms/step - loss: 0.0192 - accuracy: 0.9951 - precision_5: 0.9955 - recall_5: 0.9947 - auc_5: 0.9995 - val_loss: 0.0228 - val_accuracy: 0.9948 - val_precision_5: 0.9956 - val_recall_5: 0.9943 - val_auc_5: 0.9995 - lr: 5.0000e-04
# Epoch 10/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0261 - accuracy: 0.9956 - precision_5: 0.9961 - recall_5: 0.9949 - auc_5: 0.9995
# Epoch 10: val_loss did not improve from 0.02276
# 1219/1219 [==============================] - 561s 460ms/step - loss: 0.0261 - accuracy: 0.9956 - precision_5: 0.9961 - recall_5: 0.9949 - auc_5: 0.9995 - val_loss: 0.0439 - val_accuracy: 0.9897 - val_precision_5: 0.9905 - val_recall_5: 0.9896 - val_auc_5: 0.9985 - lr: 5.0000e-04
# Epoch 11/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0220 - accuracy: 0.9946 - precision_5: 0.9952 - recall_5: 0.9943 - auc_5: 0.9995
# Epoch 11: val_loss did not improve from 0.02276
# 1219/1219 [==============================] - 563s 462ms/step - loss: 0.0220 - accuracy: 0.9946 - precision_5: 0.9952 - recall_5: 0.9943 - auc_5: 0.9995 - val_loss: 0.0294 - val_accuracy: 0.9946 - val_precision_5: 0.9950 - val_recall_5: 0.9946 - val_auc_5: 0.9990 - lr: 5.0000e-04
# Epoch 12/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0147 - accuracy: 0.9964 - precision_5: 0.9967 - recall_5: 0.9961 - auc_5: 0.9997
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 12: val_loss did not improve from 0.02276
# 1219/1219 [==============================] - 568s 465ms/step - loss: 0.0147 - accuracy: 0.9964 - precision_5: 0.9967 - recall_5: 0.9961 - auc_5: 0.9997 - val_loss: 0.0372 - val_accuracy: 0.9934 - val_precision_5: 0.9939 - val_recall_5: 0.9928 - val_auc_5: 0.9985 - lr: 5.0000e-04
# Epoch 13/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0116 - accuracy: 0.9973 - precision_5: 0.9976 - recall_5: 0.9969 - auc_5: 0.9998
# Epoch 13: val_loss improved from 0.02276 to 0.02138, saving model to C:\Users\bheja\OneDrive\Desktop\models\densenet121_crop.h5
# 1219/1219 [==============================] - 561s 460ms/step - loss: 0.0116 - accuracy: 0.9973 - precision_5: 0.9976 - recall_5: 0.9969 - auc_5: 0.9998 - val_loss: 0.0214 - val_accuracy: 0.9955 - val_precision_5: 0.9960 - val_recall_5: 0.9949 - val_auc_5: 0.9994 - lr: 2.5000e-04
# Epoch 14/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0069 - accuracy: 0.9983 - precision_5: 0.9984 - recall_5: 0.9980 - auc_5: 0.9999
# Epoch 14: val_loss did not improve from 0.02138
# 1219/1219 [==============================] - 562s 461ms/step - loss: 0.0069 - accuracy: 0.9983 - precision_5: 0.9984 - recall_5: 0.9980 - auc_5: 0.9999 - val_loss: 0.0263 - val_accuracy: 0.9952 - val_precision_5: 0.9955 - val_recall_5: 0.9950 - val_auc_5: 0.9991 - lr: 2.5000e-04
# Epoch 15/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0120 - accuracy: 0.9978 - precision_5: 0.9981 - recall_5: 0.9977 - auc_5: 0.9998
# Epoch 15: val_loss improved from 0.02138 to 0.02000, saving model to C:\Users\bheja\OneDrive\Desktop\models\densenet121_crop.h5
# 1219/1219 [==============================] - 564s 463ms/step - loss: 0.0120 - accuracy: 0.9978 - precision_5: 0.9981 - recall_5: 0.9977 - auc_5: 0.9998 - val_loss: 0.0200 - val_accuracy: 0.9955 - val_precision_5: 0.9960 - val_recall_5: 0.9954 - val_auc_5: 0.9994 - lr: 2.5000e-04
# Epoch 16/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0080 - accuracy: 0.9982 - precision_5: 0.9983 - recall_5: 0.9981 - auc_5: 0.9998
# Epoch 16: val_loss did not improve from 0.02000
# 1219/1219 [==============================] - 565s 463ms/step - loss: 0.0080 - accuracy: 0.9982 - precision_5: 0.9983 - recall_5: 0.9981 - auc_5: 0.9998 - val_loss: 0.0292 - val_accuracy: 0.9949 - val_precision_5: 0.9951 - val_recall_5: 0.9946 - val_auc_5: 0.9991 - lr: 2.5000e-04
# Epoch 17/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0077 - accuracy: 0.9984 - precision_5: 0.9986 - recall_5: 0.9983 - auc_5: 0.9998
# Epoch 17: val_loss did not improve from 0.02000
# 1219/1219 [==============================] - 572s 469ms/step - loss: 0.0077 - accuracy: 0.9984 - precision_5: 0.9986 - recall_5: 0.9983 - auc_5: 0.9998 - val_loss: 0.0223 - val_accuracy: 0.9966 - val_precision_5: 0.9968 - val_recall_5: 0.9966 - val_auc_5: 0.9992 - lr: 2.5000e-04
# Epoch 18/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0053 - accuracy: 0.9989 - precision_5: 0.9990 - recall_5: 0.9988 - auc_5: 0.9998
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 18: val_loss did not improve from 0.02000
# 1219/1219 [==============================] - 569s 467ms/step - loss: 0.0053 - accuracy: 0.9989 - precision_5: 0.9990 - recall_5: 0.9988 - auc_5: 0.9998 - val_loss: 0.0240 - val_accuracy: 0.9964 - val_precision_5: 0.9966 - val_recall_5: 0.9964 - val_auc_5: 0.9990 - lr: 2.5000e-04
# Epoch 19/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0052 - accuracy: 0.9989 - precision_5: 0.9989 - recall_5: 0.9988 - auc_5: 0.9999
# Epoch 19: val_loss did not improve from 0.02000
# 1219/1219 [==============================] - 558s 458ms/step - loss: 0.0052 - accuracy: 0.9989 - precision_5: 0.9989 - recall_5: 0.9988 - auc_5: 0.9999 - val_loss: 0.0239 - val_accuracy: 0.9967 - val_precision_5: 0.9968 - val_recall_5: 0.9966 - val_auc_5: 0.9992 - lr: 1.2500e-04
# Epoch 20/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 0.9992 - precision_5: 0.9993 - recall_5: 0.9991 - auc_5: 1.0000
# Epoch 20: val_loss did not improve from 0.02000
# 1219/1219 [==============================] - 581s 476ms/step - loss: 0.0026 - accuracy: 0.9992 - precision_5: 0.9993 - recall_5: 0.9991 - auc_5: 1.0000 - val_loss: 0.0230 - val_accuracy: 0.9969 - val_precision_5: 0.9971 - val_recall_5: 0.9968 - val_auc_5: 0.9993 - lr: 1.2500e-04
# Epoch 21/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.9995 - precision_5: 0.9995 - recall_5: 0.9994 - auc_5: 1.0000
# Epoch 21: val_loss improved from 0.02000 to 0.01787, saving model to C:\Users\bheja\OneDrive\Desktop\models\densenet121_crop.h5
# 1219/1219 [==============================] - 581s 476ms/step - loss: 0.0016 - accuracy: 0.9995 - precision_5: 0.9995 - recall_5: 0.9994 - auc_5: 1.0000 - val_loss: 0.0179 - val_accuracy: 0.9970 - val_precision_5: 0.9971 - val_recall_5: 0.9970 - val_auc_5: 0.9994 - lr: 1.2500e-04
# Epoch 22/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0043 - accuracy: 0.9992 - precision_5: 0.9992 - recall_5: 0.9992 - auc_5: 1.0000
# Epoch 22: val_loss did not improve from 0.01787
# 1219/1219 [==============================] - 607s 498ms/step - loss: 0.0043 - accuracy: 0.9992 - precision_5: 0.9992 - recall_5: 0.9992 - auc_5: 1.0000 - val_loss: 0.0224 - val_accuracy: 0.9967 - val_precision_5: 0.9968 - val_recall_5: 0.9967 - val_auc_5: 0.9992 - lr: 1.2500e-04
# Epoch 23/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0050 - accuracy: 0.9993 - precision_5: 0.9993 - recall_5: 0.9991 - auc_5: 0.9999
# Epoch 23: val_loss improved from 0.01787 to 0.01744, saving model to C:\Users\bheja\OneDrive\Desktop\models\densenet121_crop.h5
# 1219/1219 [==============================] - 910s 747ms/step - loss: 0.0050 - accuracy: 0.9993 - precision_5: 0.9993 - recall_5: 0.9991 - auc_5: 0.9999 - val_loss: 0.0174 - val_accuracy: 0.9974 - val_precision_5: 0.9975 - val_recall_5: 0.9973 - val_auc_5: 0.9993 - lr: 1.2500e-04
# Epoch 24/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 0.9995 - precision_5: 0.9995 - recall_5: 0.9994 - auc_5: 1.0000
# Epoch 24: val_loss did not improve from 0.01744
# 1219/1219 [==============================] - 929s 762ms/step - loss: 0.0028 - accuracy: 0.9995 - precision_5: 0.9995 - recall_5: 0.9994 - auc_5: 1.0000 - val_loss: 0.0193 - val_accuracy: 0.9974 - val_precision_5: 0.9976 - val_recall_5: 0.9974 - val_auc_5: 0.9993 - lr: 1.2500e-04
# Epoch 25/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9992 - precision_5: 0.9993 - recall_5: 0.9991 - auc_5: 1.0000
# Epoch 25: val_loss did not improve from 0.01744
# 1219/1219 [==============================] - 622s 510ms/step - loss: 0.0027 - accuracy: 0.9992 - precision_5: 0.9993 - recall_5: 0.9991 - auc_5: 1.0000 - val_loss: 0.0197 - val_accuracy: 0.9969 - val_precision_5: 0.9971 - val_recall_5: 0.9969 - val_auc_5: 0.9993 - lr: 1.2500e-04
# Epoch 26/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9996 - precision_5: 0.9996 - recall_5: 0.9996 - auc_5: 0.9999
# Epoch 26: val_loss improved from 0.01744 to 0.01566, saving model to C:\Users\bheja\OneDrive\Desktop\models\densenet121_crop.h5
# 1219/1219 [==============================] - 579s 475ms/step - loss: 0.0017 - accuracy: 0.9996 - precision_5: 0.9996 - recall_5: 0.9996 - auc_5: 0.9999 - val_loss: 0.0157 - val_accuracy: 0.9977 - val_precision_5: 0.9979 - val_recall_5: 0.9977 - val_auc_5: 0.9994 - lr: 1.2500e-04
# Epoch 27/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 0.9996 - precision_5: 0.9996 - recall_5: 0.9995 - auc_5: 0.9999
# Epoch 27: val_loss improved from 0.01566 to 0.01552, saving model to C:\Users\bheja\OneDrive\Desktop\models\densenet121_crop.h5
# 1219/1219 [==============================] - 577s 473ms/step - loss: 0.0029 - accuracy: 0.9996 - precision_5: 0.9996 - recall_5: 0.9995 - auc_5: 0.9999 - val_loss: 0.0155 - val_accuracy: 0.9976 - val_precision_5: 0.9976 - val_recall_5: 0.9973 - val_auc_5: 0.9996 - lr: 1.2500e-04
# Epoch 28/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 0.9994 - precision_5: 0.9994 - recall_5: 0.9994 - auc_5: 0.9999
# Epoch 28: val_loss did not improve from 0.01552
# 1219/1219 [==============================] - 573s 470ms/step - loss: 0.0029 - accuracy: 0.9994 - precision_5: 0.9994 - recall_5: 0.9994 - auc_5: 0.9999 - val_loss: 0.0252 - val_accuracy: 0.9968 - val_precision_5: 0.9969 - val_recall_5: 0.9968 - val_auc_5: 0.9991 - lr: 1.2500e-04
# Epoch 29/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 0.9992 - precision_5: 0.9992 - recall_5: 0.9992 - auc_5: 0.9999
# Epoch 29: val_loss did not improve from 0.01552
# 1219/1219 [==============================] - 570s 468ms/step - loss: 0.0028 - accuracy: 0.9992 - precision_5: 0.9992 - recall_5: 0.9992 - auc_5: 0.9999 - val_loss: 0.0192 - val_accuracy: 0.9969 - val_precision_5: 0.9970 - val_recall_5: 0.9968 - val_auc_5: 0.9994 - lr: 1.2500e-04
# Epoch 30/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9994 - precision_5: 0.9994 - recall_5: 0.9994 - auc_5: 1.0000
# Epoch 30: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 30: val_loss did not improve from 0.01552
# 1219/1219 [==============================] - 564s 463ms/step - loss: 0.0021 - accuracy: 0.9994 - precision_5: 0.9994 - recall_5: 0.9994 - auc_5: 1.0000 - val_loss: 0.0203 - val_accuracy: 0.9971 - val_precision_5: 0.9972 - val_recall_5: 0.9971 - val_auc_5: 0.9993 - lr: 1.2500e-04
# Epoch 31/50
# 1219/1219 [==============================] - ETA: 0s - loss: 7.0796e-04 - accuracy: 0.9997 - precision_5: 0.9998 - recall_5: 0.9997 - auc_5: 1.0000
# Epoch 31: val_loss did not improve from 0.01552
# 1219/1219 [==============================] - 570s 468ms/step - loss: 7.0796e-04 - accuracy: 0.9997 - precision_5: 0.9998 - recall_5: 0.9997 - auc_5: 1.0000 - val_loss: 0.0213 - val_accuracy: 0.9972 - val_precision_5: 0.9973 - val_recall_5: 0.9972 - val_auc_5: 0.9992 - lr: 6.2500e-05
# Epoch 32/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.9997 - precision_5: 0.9997 - recall_5: 0.9997 - auc_5: 1.0000
# Epoch 32: val_loss did not improve from 0.01552
# 1219/1219 [==============================] - 567s 465ms/step - loss: 0.0016 - accuracy: 0.9997 - precision_5: 0.9997 - recall_5: 0.9997 - auc_5: 1.0000 - val_loss: 0.0164 - val_accuracy: 0.9973 - val_precision_5: 0.9974 - val_recall_5: 0.9973 - val_auc_5: 0.9995 - lr: 6.2500e-05
# Epoch 33/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0031 - accuracy: 0.9995 - precision_5: 0.9995 - recall_5: 0.9995 - auc_5: 1.0000
# Epoch 33: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 33: val_loss did not improve from 0.01552
# 1219/1219 [==============================] - 571s 468ms/step - loss: 0.0031 - accuracy: 0.9995 - precision_5: 0.9995 - recall_5: 0.9995 - auc_5: 1.0000 - val_loss: 0.0180 - val_accuracy: 0.9969 - val_precision_5: 0.9970 - val_recall_5: 0.9969 - val_auc_5: 0.9994 - lr: 6.2500e-05
# Epoch 34/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 0.9997 - precision_5: 0.9997 - recall_5: 0.9997 - auc_5: 1.0000
# Epoch 34: val_loss did not improve from 0.01552
# 1219/1219 [==============================] - 571s 468ms/step - loss: 0.0020 - accuracy: 0.9997 - precision_5: 0.9997 - recall_5: 0.9997 - auc_5: 1.0000 - val_loss: 0.0185 - val_accuracy: 0.9972 - val_precision_5: 0.9973 - val_recall_5: 0.9972 - val_auc_5: 0.9993 - lr: 3.1250e-05
# Epoch 35/50
# 1219/1219 [==============================] - ETA: 0s - loss: 9.6278e-04 - accuracy: 0.9997 - precision_5: 0.9997 - recall_5: 0.9997 - auc_5: 1.0000
# Epoch 35: val_loss did not improve from 0.01552
# 1219/1219 [==============================] - 576s 472ms/step - loss: 9.6278e-04 - accuracy: 0.9997 - precision_5: 0.9997 - recall_5: 0.9997 - auc_5: 1.0000 - val_loss: 0.0177 - val_accuracy: 0.9974 - val_precision_5: 0.9975 - val_recall_5: 0.9974 - val_auc_5: 0.9993 - lr: 3.1250e-05
# Epoch 36/50
# 1219/1219 [==============================] - ETA: 0s - loss: 7.5389e-04 - accuracy: 0.9998 - precision_5: 0.9998 - recall_5: 0.9998 - auc_5: 1.0000
# Epoch 36: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 36: val_loss did not improve from 0.01552
# 1219/1219 [==============================] - 599s 491ms/step - loss: 7.5389e-04 - accuracy: 0.9998 - precision_5: 0.9998 - recall_5: 0.9998 - auc_5: 1.0000 - val_loss: 0.0186 - val_accuracy: 0.9973 - val_precision_5: 0.9974 - val_recall_5: 0.9973 - val_auc_5: 0.9994 - lr: 3.1250e-05
# Epoch 37/50
# 1219/1219 [==============================] - ETA: 0s - loss: 7.0346e-04 - accuracy: 0.9998 - precision_5: 0.9998 - recall_5: 0.9998 - auc_5: 1.0000
# Epoch 37: val_loss did not improve from 0.01552
# 1219/1219 [==============================] - 571s 469ms/step - loss: 7.0346e-04 - accuracy: 0.9998 - precision_5: 0.9998 - recall_5: 0.9998 - auc_5: 1.0000 - val_loss: 0.0183 - val_accuracy: 0.9972 - val_precision_5: 0.9973 - val_recall_5: 0.9972 - val_auc_5: 0.9993 - lr: 1.5625e-05

# %%
import matplotlib.pyplot as plt

# Plot Training vs Validation Loss
plt.figure(figsize=(12, 6))
plt.plot(history_densenet.history['loss'], label='Training Loss')
plt.plot(history_densenet.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training vs. Validation Loss')
plt.legend()
plt.grid()
plt.show()

# Plot Training vs Validation Accuracy
plt.figure(figsize=(12, 6))
plt.plot(history_densenet.history['accuracy'], label='Training Accuracy')
plt.plot(history_densenet.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training vs. Validation Accuracy')
plt.legend()
plt.grid()
plt.show()

# Plot Training vs Validation Precision
plt.figure(figsize=(12, 6))
plt.plot(history_densenet.history['precision_5'], label='Training Precision')
plt.plot(history_densenet.history['val_precision_5'], label='Validation Precision')
plt.xlabel('Epochs')
plt.ylabel('Precision')
plt.title('Training vs. Validation Precision')
plt.legend()
plt.grid()
plt.show()

# Plot Training vs Validation Recall
plt.figure(figsize=(12, 6))
plt.plot(history_densenet.history['recall_5'], label='Training Recall')
plt.plot(history_densenet.history['val_recall_5'], label='Validation Recall')
plt.xlabel('Epochs')
plt.ylabel('Recall')
plt.title('Training vs. Validation Recall')
plt.legend()
plt.grid()
plt.show()

# Plot Training vs Validation AUC
plt.figure(figsize=(12, 6))
plt.plot(history_densenet.history['auc_5'], label='Training AUC')
plt.plot(history_densenet.history['val_auc_5'], label='Validation AUC')
plt.xlabel('Epochs')
plt.ylabel('AUC')
plt.title('Training vs. Validation AUC')
plt.legend()
plt.grid()
plt.show()

# %%
# Print the keys of the training history
print(history_densenet.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'precision_5', 'recall_5', 'auc_5', 'val_loss', 'val_accuracy', 'val_precision_5', 'val_recall_5', 'val_auc_5', 'lr'])

# %% [markdown]
# ### EfficientNetB0 ---- Did not run (Resource exhausted) -- laptop gpu rtx 3050

# %%
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout  # Add GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.metrics import Precision, Recall, AUC


# Load EfficientNetB0 with pre-trained ImageNet weights
base_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Custom layers on top of EfficientNetB0
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.4)(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.4)(x)
output = Dense(len(classes_list), activation='softmax')(x)

# Define and compile the EfficientNetB0 model
efficientnet_model = Model(inputs=base_model.input, outputs=output)
efficientnet_model.compile(optimizer=Adam(learning_rate=1e-3),
                           loss='categorical_crossentropy',
                           metrics=['accuracy', Precision(), Recall(), AUC()])

# Callbacks for EfficientNetB0
checkpoint_efficientnet = ModelCheckpoint(filepath=r'C:\Users\bheja\OneDrive\Desktop\models\efficientb0_crop.h5', monitor='val_loss', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-7, verbose=1)
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)


# Train the EfficientNetB0 model
history_efficientnet = efficientnet_model.fit(
    train_generator_crop,
    epochs=50,
    batch_size=8,  # cos Resource Exhuasted
    validation_data=test_seen_generator_crop,
    class_weight=class_weights_crop_dict,
    callbacks=[reduce_lr, early_stop, checkpoint_efficientnet]
)
# Out:
# Epoch 1/50
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Cell In[19], line 34
#      30 early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
#      33 # Train the EfficientNetB0 model
# ---> 34 history_efficientnet = efficientnet_model.fit(
#      35     train_generator_crop,
#      36     epochs=50,
#      37     batch_size=8,  # cos Resource Exhuasted
#      38     validation_data=test_seen_generator_crop,
#      39     class_weight=class_weights_crop_dict,
#      40     callbacks=[reduce_lr, early_stop, checkpoint_efficientnet]
#      41 )
#
# File ~\.conda\envs\mysha\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\.conda\envs\mysha\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# ResourceExhaustedError: Graph execution error:
#
# Detected at node 'model_9/block2b_bn/FusedBatchNormV3' defined at (most recent call last):
#     File "C:\Users\bheja\.conda\envs\mysha\lib\runpy.py", line 197, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "C:\Users\bheja\.conda\envs\mysha\lib\runpy.py", line 87, in _run_code
#       exec(code, run_globals)
#     File "C:\Users\bheja\.conda\envs\mysha\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#       app.launch_new_instance()
#     File "C:\Users\bheja\.conda\envs\mysha\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#       app.start()
#     File "C:\Users\bheja\.conda\envs\mysha\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#       self.io_loop.start()
#     File "C:\Users\bheja\.conda\envs\mysha\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#       self.asyncio_loop.run_forever()
#     File "C:\Users\bheja\.conda\envs\mysha\lib\asyncio\base_events.py", line 601, in run_forever
#       self._run_once()
#     File "C:\Users\bheja\.conda\envs\mysha\lib\asyncio\base_events.py", line 1905, in _run_once
#       handle._run()
#     File "C:\Users\bheja\.conda\envs\mysha\lib\asyncio\events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "C:\Users\bheja\.conda\envs\mysha\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#       await self.process_one()
#     File "C:\Users\bheja\.conda\envs\mysha\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#       await dispatch(*args)
#     File "C:\Users\bheja\.conda\envs\mysha\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#       await result
#     File "C:\Users\bheja\.conda\envs\mysha\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#       await super().execute_request(stream, ident, parent)
#     File "C:\Users\bheja\.conda\envs\mysha\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#       reply_content = await reply_content
#     File "C:\Users\bheja\.conda\envs\mysha\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#       res = shell.run_cell(
#     File "C:\Users\bheja\.conda\envs\mysha\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "C:\Users\bheja\.conda\envs\mysha\lib\site-packages\IPython\core\interactiveshell.py", line 3048, in run_cell
#       result = self._run_cell(
#     File "C:\Users\bheja\.conda\envs\mysha\lib\site-packages\IPython\core\interactiveshell.py", line 3103, in _run_cell
#       result = runner(coro)
#     File "C:\Users\bheja\.conda\envs\mysha\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "C:\Users\bheja\.conda\envs\mysha\lib\site-packages\IPython\core\interactiveshell.py", line 3308, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "C:\Users\bheja\.conda\envs\mysha\lib\site-packages\IPython\core\interactiveshell.py", line 3490, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "C:\Users\bheja\.conda\envs\mysha\lib\site-packages\IPython\core\interactiveshell.py", line 3550, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "C:\Users\bheja\AppData\Local\Temp\ipykernel_42188\1691588618.py", line 34, in <module>
#       history_efficientnet = efficientnet_model.fit(
#     File "C:\Users\bheja\.conda\envs\mysha\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\bheja\.conda\envs\mysha\lib\site-packages\keras\engine\training.py", line 1564, in fit
#       tmp_logs = self.train_function(iterator)
#     File "C:\Users\bheja\.conda\envs\mysha\lib\site-packages\keras\engine\training.py", line 1160, in train_function
#       return step_function(self, iterator)
#     File "C:\Users\bheja\.conda\envs\mysha\lib\site-packages\keras\engine\training.py", line 1146, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\bheja\.conda\envs\mysha\lib\site-packages\keras\engine\training.py", line 1135, in run_step
#       outputs = model.train_step(data)
#     File "C:\Users\bheja\.conda\envs\mysha\lib\site-packages\keras\engine\training.py", line 993, in train_step
#       y_pred = self(x, training=True)
#     File "C:\Users\bheja\.conda\envs\mysha\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\bheja\.conda\envs\mysha\lib\site-packages\keras\engine\training.py", line 557, in __call__
#       return super().__call__(*args, **kwargs)
#     File "C:\Users\bheja\.conda\envs\mysha\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\bheja\.conda\envs\mysha\lib\site-packages\keras\engine\base_layer.py", line 1097, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "C:\Users\bheja\.conda\envs\mysha\lib\site-packages\keras\utils\traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\bheja\.conda\envs\mysha\lib\site-packages\keras\engine\functional.py", line 510, in call
#       return self._run_internal_graph(inputs, training=training, mask=mask)
#     File "C:\Users\bheja\.conda\envs\mysha\lib\site-packages\keras\engine\functional.py", line 667, in _run_internal_graph
#       outputs = node.layer(*args, **kwargs)
#     File "C:\Users\bheja\.conda\envs\mysha\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\bheja\.conda\envs\mysha\lib\site-packages\keras\engine\base_layer.py", line 1097, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "C:\Users\bheja\.conda\envs\mysha\lib\site-packages\keras\utils\traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\bheja\.conda\envs\mysha\lib\site-packages\keras\layers\normalization\batch_normalization.py", line 850, in call
#       outputs = self._fused_batch_norm(inputs, training=training)
#     File "C:\Users\bheja\.conda\envs\mysha\lib\site-packages\keras\layers\normalization\batch_normalization.py", line 660, in _fused_batch_norm
#       output, mean, variance = control_flow_util.smart_cond(
#     File "C:\Users\bheja\.conda\envs\mysha\lib\site-packages\keras\utils\control_flow_util.py", line 108, in smart_cond
#       return tf.__internal__.smart_cond.smart_cond(
#     File "C:\Users\bheja\.conda\envs\mysha\lib\site-packages\keras\layers\normalization\batch_normalization.py", line 634, in _fused_batch_norm_training
#       return tf.compat.v1.nn.fused_batch_norm(
# Node: 'model_9/block2b_bn/FusedBatchNormV3'
# OOM when allocating tensor with shape[32,144,56,56] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node model_9/block2b_bn/FusedBatchNormV3}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_train_function_178940]

# %% [markdown]
# # Disease model

# %% [markdown]
# ## Balancing the data

# %%
from sklearn.utils.class_weight import compute_class_weight
import numpy as np

# Extract the disease class labels from the training data
y_disease = train_data['disease_class'].astype(str).values  # Convert to string since class_weight requires classes as strings or integers

# Calculate class weights for the disease classes
disease_classes = np.unique(y_disease)  # Get unique disease classes
class_weights_disease = compute_class_weight('balanced', classes=disease_classes, y=y_disease)
class_weights_disease_dict = dict(zip(disease_classes, class_weights_disease))

# Print the class weights for disease classes
print("Class Weights for Disease Classes:")
print(class_weights_disease_dict)
# Out:
# Class Weights for Disease Classes:
# {'0': 0.22542881423541858, '1': 3.7286288009179573, '10': 0.4257870082222295, '11': 0.5218822773628844, '12': 1.1165707413452453, '13': 0.7976190476190477, '14': 1.994475985883075, '15': 2.417782738095238, '16': 1.2753139717425432, '17': 1.415287456445993, '18': 1.6345573440643864, '19': 0.43062549695202756, '2': 1.3573517126148704, '20': 6.04839460214053, '3': 8.44025974025974, '4': 0.7575916535524858, '5': 4.539993014320642, '6': 1.9463911350703804, '7': 2.326888650196921, '8': 1.6895879370856624, '9': 2.2425810904071772}

# %% [markdown]
# ## image processing (run if kernel restarted)

# %%
import cv2
import numpy as np
import os

# Function for image pre-processing
def preprocess_image(image_path):
    # Read the image in RGB format
    image = cv2.imread(image_path)
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    
    # Convert the image from RGB to Lab color space
    image_lab = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2Lab)
    
    # Apply CLAHE to the L channel
    l_channel, a_channel, b_channel = cv2.split(image_lab)
    clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8, 8))
    l_channel = clahe.apply(l_channel)
    
    # Merge the L, a, b channels and convert back to RGB color space
    image_lab = cv2.merge((l_channel, a_channel, b_channel))
    enhanced_image = cv2.cvtColor(image_lab, cv2.COLOR_Lab2RGB)
    
    # Apply Adaptive Median Filter to remove noise
    enhanced_image_filtered = cv2.medianBlur(enhanced_image, 3)
    
    return enhanced_image_filtered

# Test the preprocessing function on a sample image
sample_image_path = os.path.join(plant_vil_dir, train_data.iloc[0]['image_name'])
processed_image = preprocess_image(sample_image_path)

# Display the original and preprocessed images for comparison
import matplotlib.pyplot as plt

original_image = cv2.imread(sample_image_path)
original_image_rgb = cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.imshow(original_image_rgb)
plt.title('Original Image')

plt.subplot(1, 2, 2)
plt.imshow(processed_image)
plt.title('Preprocessed Image')

plt.show()

# %% [markdown]
# ## Generators

# %%
train_data["disease_class"] = train_data["disease_class"].astype(str)
test_seen_data["disease_class"] = test_seen_data["disease_class"].astype(str)
test_unseen_data["disease_class"] = test_unseen_data["disease_class"].astype(str)
doc_unseen_data["disease_class"] = doc_unseen_data["disease_class"].astype(str)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Create data augmentation generator for training
train_datagen_disease = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

# Create data generator for testing --without augmentation, only rescale--
test_datagen_disease = ImageDataGenerator(rescale=1./255)

# Create the training data generator for disease classes
train_generator_disease = train_datagen_disease.flow_from_dataframe(
    dataframe=train_data,
    directory=plant_vil_dir,
    x_col="image_name",
    y_col="disease_class",
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    shuffle=True
)

# Use the class indices from the training generator
classes_list_disease = list(train_generator_disease.class_indices.keys())

# Use the same classes_list_disease to ensure consistency in the testing generators
test_seen_generator_disease = test_datagen_disease.flow_from_dataframe(
    dataframe=test_seen_data,
    directory=plant_vil_dir,
    x_col="image_name",
    y_col="disease_class",
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    classes=classes_list_disease,  # Using the same classes as training generator
    shuffle=False
)

test_unseen_generator_disease = test_datagen_disease.flow_from_dataframe(
    dataframe=test_unseen_data,
    directory=plant_vil_dir,
    x_col="image_name",
    y_col="disease_class",
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    classes=classes_list_disease,  # Using the same classes as training generator
    shuffle=False
)

doc_unseen_generator_disease = test_datagen_disease.flow_from_dataframe(
    dataframe=doc_unseen_data,
    directory=plant_doc_dir,
    x_col="image_name",
    y_col="disease_class",
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    classes=classes_list_disease,  # Using the same classes as training generator
    shuffle=False
)

# Verify the class indices for the data generators again
print("Class indices for training generator (Disease):", train_generator_disease.class_indices)
print("Class indices for testing generator (Seen Disease):", test_seen_generator_disease.class_indices)
print("Class indices for testing generator (Unseen Disease):", test_unseen_generator_disease.class_indices)
print("Class indices for testing generator (Doc Unseen Disease):", doc_unseen_generator_disease.class_indices)
# Out:
# Found 38994 validated image filenames belonging to 21 classes.
# Found 10279 validated image filenames belonging to 21 classes.
# Found 216 validated image filenames belonging to 21 classes.
# Found 71 validated image filenames belonging to 21 classes.
# Class indices for training generator (Disease): {'0': 0, '1': 1, '10': 2, '11': 3, '12': 4, '13': 5, '14': 6, '15': 7, '16': 8, '17': 9, '18': 10, '19': 11, '2': 12, '20': 13, '3': 14, '4': 15, '5': 16, '6': 17, '7': 18, '8': 19, '9': 20}
# Class indices for testing generator (Seen Disease): {'0': 0, '1': 1, '10': 2, '11': 3, '12': 4, '13': 5, '14': 6, '15': 7, '16': 8, '17': 9, '18': 10, '19': 11, '2': 12, '20': 13, '3': 14, '4': 15, '5': 16, '6': 17, '7': 18, '8': 19, '9': 20}
# Class indices for testing generator (Unseen Disease): {'0': 0, '1': 1, '10': 2, '11': 3, '12': 4, '13': 5, '14': 6, '15': 7, '16': 8, '17': 9, '18': 10, '19': 11, '2': 12, '20': 13, '3': 14, '4': 15, '5': 16, '6': 17, '7': 18, '8': 19, '9': 20}
# Class indices for testing generator (Doc Unseen Disease): {'0': 0, '1': 1, '10': 2, '11': 3, '12': 4, '13': 5, '14': 6, '15': 7, '16': 8, '17': 9, '18': 10, '19': 11, '2': 12, '20': 13, '3': 14, '4': 15, '5': 16, '6': 17, '7': 18, '8': 19, '9': 20}

# %% [markdown]
# ## Training

# %%
# Convert keys of class_weights_disease_dict to integers
class_weights_disease_dict = {int(k): v for k, v in class_weights_disease_dict.items()}

# Print the updated class weights for disease classes
print("Updated Class Weights for Disease Classes:")
print(class_weights_disease_dict)
# Out:
# Updated Class Weights for Disease Classes:
# {0: 0.22542881423541858, 1: 3.7286288009179573, 10: 0.4257870082222295, 11: 0.5218822773628844, 12: 1.1165707413452453, 13: 0.7976190476190477, 14: 1.994475985883075, 15: 2.417782738095238, 16: 1.2753139717425432, 17: 1.415287456445993, 18: 1.6345573440643864, 19: 0.43062549695202756, 2: 1.3573517126148704, 20: 6.04839460214053, 3: 8.44025974025974, 4: 0.7575916535524858, 5: 4.539993014320642, 6: 1.9463911350703804, 7: 2.326888650196921, 8: 1.6895879370856624, 9: 2.2425810904071772}

# %% [markdown]
# ### Resnet50V2

# %%
from tensorflow.keras.applications import ResNet50V2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from tensorflow.keras.metrics import Precision, Recall, AUC
import numpy as np

# Load pre-trained ResNet50V2 model + higher level layers
# We're using the 'imagenet' weights and excluding the top layers
base_model = ResNet50V2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the initial layers to retain the pre-trained features
for layer in base_model.layers[:100]:
    layer.trainable = False

# Add custom layers on top
x = base_model.output
x = GlobalAveragePooling2D()(x)  # Reduce spatial dimensions
x = Dense(1024, activation='relu')(x)  # Fully connected layer
x = Dropout(0.4)(x)  # Add Dropout to prevent overfitting
x = Dense(512, activation='relu')(x)  # Fully connected layer
x = Dropout(0.4)(x)  # Add Dropout to prevent overfitting
x = Dense(256, activation='relu')(x)  # Fully connected layer
x = Dropout(0.4)(x)  # Add Dropout to prevent overfitting
output = Dense(len(classes_list_disease), activation='softmax')(x)  # Output layer with number of disease classes

# Define the model
model = Model(inputs=base_model.input, outputs=output)

# Compile the model with a higher learning rate
model.compile(optimizer=Adam(learning_rate=1e-3),
              loss='categorical_crossentropy',
              metrics=['accuracy', Precision(), Recall(), AUC()])

# Define callbacks for training
checkpoint_resnet = ModelCheckpoint(filepath=r'C:\Users\bheja\OneDrive\Desktop\models\resnet50v2_disease.h5',
                                    monitor='val_loss',
                                    save_best_only=True,
                                    save_weights_only=False,
                                    verbose=1)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',          # Monitor validation loss to decide when to reduce the learning rate
    factor=0.5,                  # Reduce learning rate by a factor of 0.5
    patience=3,                  # Number of epochs with no improvement after which learning rate will be reduced
    min_lr=1e-7,                 # Lower bound on the learning rate to prevent it from going too low
    verbose=1                    # Prints a message when learning rate is reduced
)

early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model using the training and validation generators
history_resnet_disease = model.fit(
    train_generator_disease,
    epochs=50,  # Training with transfer learning so not going for 100 as the earlier models
    batch_size=32,
    validation_data=test_seen_generator_disease,
    class_weight=class_weights_disease_dict,  # Use class weights for imbalance
    callbacks=[reduce_lr, early_stop, checkpoint_resnet]
)
# Out:
# Epoch 1/50
# 1219/1219 [==============================] - ETA: 0s - loss: 1.8515 - accuracy: 0.5136 - precision_10: 0.7022 - recall_10: 0.4318 - auc_10: 0.9128
# Epoch 1: val_loss improved from inf to 1.97826, saving model to C:\Users\bheja\OneDrive\Desktop\models\resnet50v2_disease.h5
# 1219/1219 [==============================] - 924s 752ms/step - loss: 1.8515 - accuracy: 0.5136 - precision_10: 0.7022 - recall_10: 0.4318 - auc_10: 0.9128 - val_loss: 1.9783 - val_accuracy: 0.5728 - val_precision_10: 0.6381 - val_recall_10: 0.5084 - val_auc_10: 0.9252 - lr: 0.0010
# Epoch 2/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.7651 - accuracy: 0.7510 - precision_10: 0.8199 - recall_10: 0.6926 - auc_10: 0.9753
# Epoch 2: val_loss improved from 1.97826 to 0.78450, saving model to C:\Users\bheja\OneDrive\Desktop\models\resnet50v2_disease.h5
# 1219/1219 [==============================] - 620s 508ms/step - loss: 0.7651 - accuracy: 0.7510 - precision_10: 0.8199 - recall_10: 0.6926 - auc_10: 0.9753 - val_loss: 0.7845 - val_accuracy: 0.7589 - val_precision_10: 0.7940 - val_recall_10: 0.7286 - val_auc_10: 0.9773 - lr: 0.0010
# Epoch 3/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.5725 - accuracy: 0.8228 - precision_10: 0.8672 - recall_10: 0.7836 - auc_10: 0.9841
# Epoch 3: val_loss did not improve from 0.78450
# 1219/1219 [==============================] - 539s 442ms/step - loss: 0.5725 - accuracy: 0.8228 - precision_10: 0.8672 - recall_10: 0.7836 - auc_10: 0.9841 - val_loss: 0.8088 - val_accuracy: 0.8504 - val_precision_10: 0.8675 - val_recall_10: 0.8346 - val_auc_10: 0.9751 - lr: 0.0010
# Epoch 4/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.4411 - accuracy: 0.8611 - precision_10: 0.8930 - recall_10: 0.8315 - auc_10: 0.9884
# Epoch 4: val_loss improved from 0.78450 to 0.23698, saving model to C:\Users\bheja\OneDrive\Desktop\models\resnet50v2_disease.h5
# 1219/1219 [==============================] - 528s 433ms/step - loss: 0.4411 - accuracy: 0.8611 - precision_10: 0.8930 - recall_10: 0.8315 - auc_10: 0.9884 - val_loss: 0.2370 - val_accuracy: 0.9239 - val_precision_10: 0.9372 - val_recall_10: 0.9144 - val_auc_10: 0.9958 - lr: 0.0010
# Epoch 5/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.3718 - accuracy: 0.8826 - precision_10: 0.9091 - recall_10: 0.8573 - auc_10: 0.9903
# Epoch 5: val_loss did not improve from 0.23698
# 1219/1219 [==============================] - 522s 428ms/step - loss: 0.3718 - accuracy: 0.8826 - precision_10: 0.9091 - recall_10: 0.8573 - auc_10: 0.9903 - val_loss: 0.5289 - val_accuracy: 0.8829 - val_precision_10: 0.9025 - val_recall_10: 0.8663 - val_auc_10: 0.9843 - lr: 0.0010
# Epoch 6/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.3421 - accuracy: 0.8981 - precision_10: 0.9194 - recall_10: 0.8750 - auc_10: 0.9911
# Epoch 6: val_loss did not improve from 0.23698
# 1219/1219 [==============================] - 533s 437ms/step - loss: 0.3421 - accuracy: 0.8981 - precision_10: 0.9194 - recall_10: 0.8750 - auc_10: 0.9911 - val_loss: 0.2751 - val_accuracy: 0.9184 - val_precision_10: 0.9310 - val_recall_10: 0.9086 - val_auc_10: 0.9936 - lr: 0.0010
# Epoch 7/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.3073 - accuracy: 0.9052 - precision_10: 0.9243 - recall_10: 0.8867 - auc_10: 0.9925
# Epoch 7: val_loss improved from 0.23698 to 0.15183, saving model to C:\Users\bheja\OneDrive\Desktop\models\resnet50v2_disease.h5
# 1219/1219 [==============================] - 523s 429ms/step - loss: 0.3073 - accuracy: 0.9052 - precision_10: 0.9243 - recall_10: 0.8867 - auc_10: 0.9925 - val_loss: 0.1518 - val_accuracy: 0.9538 - val_precision_10: 0.9607 - val_recall_10: 0.9480 - val_auc_10: 0.9970 - lr: 0.0010
# Epoch 8/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.2708 - accuracy: 0.9161 - precision_10: 0.9332 - recall_10: 0.8999 - auc_10: 0.9933
# Epoch 8: val_loss did not improve from 0.15183
# 1219/1219 [==============================] - 519s 425ms/step - loss: 0.2708 - accuracy: 0.9161 - precision_10: 0.9332 - recall_10: 0.8999 - auc_10: 0.9933 - val_loss: 0.3318 - val_accuracy: 0.9297 - val_precision_10: 0.9408 - val_recall_10: 0.9160 - val_auc_10: 0.9921 - lr: 0.0010
# Epoch 9/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.2913 - accuracy: 0.9090 - precision_10: 0.9276 - recall_10: 0.8925 - auc_10: 0.9926
# Epoch 9: val_loss did not improve from 0.15183
# 1219/1219 [==============================] - 519s 426ms/step - loss: 0.2913 - accuracy: 0.9090 - precision_10: 0.9276 - recall_10: 0.8925 - auc_10: 0.9926 - val_loss: 0.1884 - val_accuracy: 0.9443 - val_precision_10: 0.9547 - val_recall_10: 0.9363 - val_auc_10: 0.9960 - lr: 0.0010
# Epoch 10/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.2323 - accuracy: 0.9265 - precision_10: 0.9411 - recall_10: 0.9133 - auc_10: 0.9938
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 10: val_loss did not improve from 0.15183
# 1219/1219 [==============================] - 528s 433ms/step - loss: 0.2323 - accuracy: 0.9265 - precision_10: 0.9411 - recall_10: 0.9133 - auc_10: 0.9938 - val_loss: 0.2182 - val_accuracy: 0.9521 - val_precision_10: 0.9575 - val_recall_10: 0.9490 - val_auc_10: 0.9937 - lr: 0.0010
# Epoch 11/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.1344 - accuracy: 0.9516 - precision_10: 0.9587 - recall_10: 0.9446 - auc_10: 0.9967
# Epoch 11: val_loss improved from 0.15183 to 0.11334, saving model to C:\Users\bheja\OneDrive\Desktop\models\resnet50v2_disease.h5
# 1219/1219 [==============================] - 518s 425ms/step - loss: 0.1344 - accuracy: 0.9516 - precision_10: 0.9587 - recall_10: 0.9446 - auc_10: 0.9967 - val_loss: 0.1133 - val_accuracy: 0.9639 - val_precision_10: 0.9683 - val_recall_10: 0.9605 - val_auc_10: 0.9979 - lr: 5.0000e-04
# Epoch 12/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.1226 - accuracy: 0.9544 - precision_10: 0.9603 - recall_10: 0.9484 - auc_10: 0.9973
# Epoch 12: val_loss did not improve from 0.11334
# 1219/1219 [==============================] - 639s 525ms/step - loss: 0.1226 - accuracy: 0.9544 - precision_10: 0.9603 - recall_10: 0.9484 - auc_10: 0.9973 - val_loss: 0.1167 - val_accuracy: 0.9668 - val_precision_10: 0.9687 - val_recall_10: 0.9651 - val_auc_10: 0.9976 - lr: 5.0000e-04
# Epoch 13/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.1208 - accuracy: 0.9571 - precision_10: 0.9624 - recall_10: 0.9521 - auc_10: 0.9968
# Epoch 13: val_loss did not improve from 0.11334
# 1219/1219 [==============================] - 754s 618ms/step - loss: 0.1208 - accuracy: 0.9571 - precision_10: 0.9624 - recall_10: 0.9521 - auc_10: 0.9968 - val_loss: 0.1197 - val_accuracy: 0.9662 - val_precision_10: 0.9698 - val_recall_10: 0.9639 - val_auc_10: 0.9977 - lr: 5.0000e-04
# Epoch 14/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.1128 - accuracy: 0.9619 - precision_10: 0.9666 - recall_10: 0.9576 - auc_10: 0.9973
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 14: val_loss did not improve from 0.11334
# 1219/1219 [==============================] - 517s 424ms/step - loss: 0.1128 - accuracy: 0.9619 - precision_10: 0.9666 - recall_10: 0.9576 - auc_10: 0.9973 - val_loss: 0.1277 - val_accuracy: 0.9612 - val_precision_10: 0.9647 - val_recall_10: 0.9589 - val_auc_10: 0.9976 - lr: 5.0000e-04
# Epoch 15/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0798 - accuracy: 0.9694 - precision_10: 0.9732 - recall_10: 0.9659 - auc_10: 0.9981
# Epoch 15: val_loss improved from 0.11334 to 0.08183, saving model to C:\Users\bheja\OneDrive\Desktop\models\resnet50v2_disease.h5
# 1219/1219 [==============================] - 523s 429ms/step - loss: 0.0798 - accuracy: 0.9694 - precision_10: 0.9732 - recall_10: 0.9659 - auc_10: 0.9981 - val_loss: 0.0818 - val_accuracy: 0.9751 - val_precision_10: 0.9768 - val_recall_10: 0.9738 - val_auc_10: 0.9986 - lr: 2.5000e-04
# Epoch 16/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0659 - accuracy: 0.9759 - precision_10: 0.9782 - recall_10: 0.9734 - auc_10: 0.9986
# Epoch 16: val_loss did not improve from 0.08183
# 1219/1219 [==============================] - 528s 433ms/step - loss: 0.0659 - accuracy: 0.9759 - precision_10: 0.9782 - recall_10: 0.9734 - auc_10: 0.9986 - val_loss: 0.0871 - val_accuracy: 0.9770 - val_precision_10: 0.9785 - val_recall_10: 0.9761 - val_auc_10: 0.9977 - lr: 2.5000e-04
# Epoch 17/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0712 - accuracy: 0.9748 - precision_10: 0.9772 - recall_10: 0.9722 - auc_10: 0.9985
# Epoch 17: val_loss did not improve from 0.08183
# 1219/1219 [==============================] - 535s 439ms/step - loss: 0.0712 - accuracy: 0.9748 - precision_10: 0.9772 - recall_10: 0.9722 - auc_10: 0.9985 - val_loss: 0.0822 - val_accuracy: 0.9763 - val_precision_10: 0.9781 - val_recall_10: 0.9755 - val_auc_10: 0.9983 - lr: 2.5000e-04
# Epoch 18/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0535 - accuracy: 0.9793 - precision_10: 0.9812 - recall_10: 0.9776 - auc_10: 0.9987
# Epoch 18: val_loss improved from 0.08183 to 0.07621, saving model to C:\Users\bheja\OneDrive\Desktop\models\resnet50v2_disease.h5
# 1219/1219 [==============================] - 573s 470ms/step - loss: 0.0535 - accuracy: 0.9793 - precision_10: 0.9812 - recall_10: 0.9776 - auc_10: 0.9987 - val_loss: 0.0762 - val_accuracy: 0.9799 - val_precision_10: 0.9816 - val_recall_10: 0.9789 - val_auc_10: 0.9981 - lr: 2.5000e-04
# Epoch 19/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0559 - accuracy: 0.9788 - precision_10: 0.9807 - recall_10: 0.9773 - auc_10: 0.9988
# Epoch 19: val_loss did not improve from 0.07621
# 1219/1219 [==============================] - 860s 705ms/step - loss: 0.0559 - accuracy: 0.9788 - precision_10: 0.9807 - recall_10: 0.9773 - auc_10: 0.9988 - val_loss: 0.0767 - val_accuracy: 0.9787 - val_precision_10: 0.9804 - val_recall_10: 0.9784 - val_auc_10: 0.9981 - lr: 2.5000e-04
# Epoch 20/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0613 - accuracy: 0.9775 - precision_10: 0.9796 - recall_10: 0.9754 - auc_10: 0.9985
# Epoch 20: val_loss improved from 0.07621 to 0.07247, saving model to C:\Users\bheja\OneDrive\Desktop\models\resnet50v2_disease.h5
# 1219/1219 [==============================] - 818s 672ms/step - loss: 0.0613 - accuracy: 0.9775 - precision_10: 0.9796 - recall_10: 0.9754 - auc_10: 0.9985 - val_loss: 0.0725 - val_accuracy: 0.9801 - val_precision_10: 0.9812 - val_recall_10: 0.9792 - val_auc_10: 0.9983 - lr: 2.5000e-04
# Epoch 21/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0583 - accuracy: 0.9799 - precision_10: 0.9818 - recall_10: 0.9782 - auc_10: 0.9988
# Epoch 21: val_loss did not improve from 0.07247
# 1219/1219 [==============================] - 852s 697ms/step - loss: 0.0583 - accuracy: 0.9799 - precision_10: 0.9818 - recall_10: 0.9782 - auc_10: 0.9988 - val_loss: 0.0911 - val_accuracy: 0.9768 - val_precision_10: 0.9779 - val_recall_10: 0.9756 - val_auc_10: 0.9975 - lr: 2.5000e-04
# Epoch 22/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0488 - accuracy: 0.9814 - precision_10: 0.9832 - recall_10: 0.9798 - auc_10: 0.9988
# Epoch 22: val_loss did not improve from 0.07247
# 1219/1219 [==============================] - 834s 684ms/step - loss: 0.0488 - accuracy: 0.9814 - precision_10: 0.9832 - recall_10: 0.9798 - auc_10: 0.9988 - val_loss: 0.0735 - val_accuracy: 0.9796 - val_precision_10: 0.9810 - val_recall_10: 0.9790 - val_auc_10: 0.9984 - lr: 2.5000e-04
# Epoch 23/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0412 - accuracy: 0.9832 - precision_10: 0.9848 - recall_10: 0.9820 - auc_10: 0.9990
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 23: val_loss did not improve from 0.07247
# 1219/1219 [==============================] - 540s 443ms/step - loss: 0.0412 - accuracy: 0.9832 - precision_10: 0.9848 - recall_10: 0.9820 - auc_10: 0.9990 - val_loss: 0.0949 - val_accuracy: 0.9760 - val_precision_10: 0.9772 - val_recall_10: 0.9752 - val_auc_10: 0.9975 - lr: 2.5000e-04
# Epoch 24/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0435 - accuracy: 0.9838 - precision_10: 0.9851 - recall_10: 0.9823 - auc_10: 0.9990
# Epoch 24: val_loss improved from 0.07247 to 0.06456, saving model to C:\Users\bheja\OneDrive\Desktop\models\resnet50v2_disease.h5
# 1219/1219 [==============================] - 527s 432ms/step - loss: 0.0435 - accuracy: 0.9838 - precision_10: 0.9851 - recall_10: 0.9823 - auc_10: 0.9990 - val_loss: 0.0646 - val_accuracy: 0.9822 - val_precision_10: 0.9834 - val_recall_10: 0.9812 - val_auc_10: 0.9983 - lr: 1.2500e-04
# Epoch 25/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0354 - accuracy: 0.9861 - precision_10: 0.9869 - recall_10: 0.9852 - auc_10: 0.9991
# Epoch 25: val_loss did not improve from 0.06456
# 1219/1219 [==============================] - 511s 419ms/step - loss: 0.0354 - accuracy: 0.9861 - precision_10: 0.9869 - recall_10: 0.9852 - auc_10: 0.9991 - val_loss: 0.0719 - val_accuracy: 0.9817 - val_precision_10: 0.9828 - val_recall_10: 0.9811 - val_auc_10: 0.9981 - lr: 1.2500e-04
# Epoch 26/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0333 - accuracy: 0.9863 - precision_10: 0.9872 - recall_10: 0.9855 - auc_10: 0.9992
# Epoch 26: val_loss did not improve from 0.06456
# 1219/1219 [==============================] - 514s 422ms/step - loss: 0.0333 - accuracy: 0.9863 - precision_10: 0.9872 - recall_10: 0.9855 - auc_10: 0.9992 - val_loss: 0.0646 - val_accuracy: 0.9819 - val_precision_10: 0.9826 - val_recall_10: 0.9812 - val_auc_10: 0.9985 - lr: 1.2500e-04
# Epoch 27/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0297 - accuracy: 0.9870 - precision_10: 0.9878 - recall_10: 0.9862 - auc_10: 0.9993
# Epoch 27: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 27: val_loss did not improve from 0.06456
# 1219/1219 [==============================] - 521s 427ms/step - loss: 0.0297 - accuracy: 0.9870 - precision_10: 0.9878 - recall_10: 0.9862 - auc_10: 0.9993 - val_loss: 0.0670 - val_accuracy: 0.9831 - val_precision_10: 0.9842 - val_recall_10: 0.9826 - val_auc_10: 0.9982 - lr: 1.2500e-04
# Epoch 28/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0304 - accuracy: 0.9885 - precision_10: 0.9891 - recall_10: 0.9881 - auc_10: 0.9993
# Epoch 28: val_loss improved from 0.06456 to 0.06403, saving model to C:\Users\bheja\OneDrive\Desktop\models\resnet50v2_disease.h5
# 1219/1219 [==============================] - 532s 436ms/step - loss: 0.0304 - accuracy: 0.9885 - precision_10: 0.9891 - recall_10: 0.9881 - auc_10: 0.9993 - val_loss: 0.0640 - val_accuracy: 0.9836 - val_precision_10: 0.9844 - val_recall_10: 0.9832 - val_auc_10: 0.9986 - lr: 6.2500e-05
# Epoch 29/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0250 - accuracy: 0.9894 - precision_10: 0.9902 - recall_10: 0.9889 - auc_10: 0.9995
# Epoch 29: val_loss improved from 0.06403 to 0.06106, saving model to C:\Users\bheja\OneDrive\Desktop\models\resnet50v2_disease.h5
# 1219/1219 [==============================] - 527s 432ms/step - loss: 0.0250 - accuracy: 0.9894 - precision_10: 0.9902 - recall_10: 0.9889 - auc_10: 0.9995 - val_loss: 0.0611 - val_accuracy: 0.9857 - val_precision_10: 0.9862 - val_recall_10: 0.9852 - val_auc_10: 0.9983 - lr: 6.2500e-05
# Epoch 30/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0268 - accuracy: 0.9900 - precision_10: 0.9906 - recall_10: 0.9895 - auc_10: 0.9995
# Epoch 30: val_loss did not improve from 0.06106
# 1219/1219 [==============================] - 690s 566ms/step - loss: 0.0268 - accuracy: 0.9900 - precision_10: 0.9906 - recall_10: 0.9895 - auc_10: 0.9995 - val_loss: 0.0629 - val_accuracy: 0.9846 - val_precision_10: 0.9855 - val_recall_10: 0.9843 - val_auc_10: 0.9983 - lr: 6.2500e-05
# Epoch 31/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0245 - accuracy: 0.9906 - precision_10: 0.9912 - recall_10: 0.9901 - auc_10: 0.9995
# Epoch 31: val_loss did not improve from 0.06106
# 1219/1219 [==============================] - 528s 433ms/step - loss: 0.0245 - accuracy: 0.9906 - precision_10: 0.9912 - recall_10: 0.9901 - auc_10: 0.9995 - val_loss: 0.0680 - val_accuracy: 0.9833 - val_precision_10: 0.9845 - val_recall_10: 0.9827 - val_auc_10: 0.9984 - lr: 6.2500e-05
# Epoch 32/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0251 - accuracy: 0.9904 - precision_10: 0.9912 - recall_10: 0.9899 - auc_10: 0.9994
# Epoch 32: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 32: val_loss did not improve from 0.06106
# 1219/1219 [==============================] - 618s 507ms/step - loss: 0.0251 - accuracy: 0.9904 - precision_10: 0.9912 - recall_10: 0.9899 - auc_10: 0.9994 - val_loss: 0.0689 - val_accuracy: 0.9848 - val_precision_10: 0.9856 - val_recall_10: 0.9846 - val_auc_10: 0.9980 - lr: 6.2500e-05
# Epoch 33/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0228 - accuracy: 0.9915 - precision_10: 0.9922 - recall_10: 0.9911 - auc_10: 0.9995
# Epoch 33: val_loss did not improve from 0.06106
# 1219/1219 [==============================] - 604s 495ms/step - loss: 0.0228 - accuracy: 0.9915 - precision_10: 0.9922 - recall_10: 0.9911 - auc_10: 0.9995 - val_loss: 0.0683 - val_accuracy: 0.9838 - val_precision_10: 0.9843 - val_recall_10: 0.9834 - val_auc_10: 0.9979 - lr: 3.1250e-05
# Epoch 34/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0228 - accuracy: 0.9909 - precision_10: 0.9915 - recall_10: 0.9906 - auc_10: 0.9995
# Epoch 34: val_loss did not improve from 0.06106
# 1219/1219 [==============================] - 739s 606ms/step - loss: 0.0228 - accuracy: 0.9909 - precision_10: 0.9915 - recall_10: 0.9906 - auc_10: 0.9995 - val_loss: 0.0660 - val_accuracy: 0.9841 - val_precision_10: 0.9847 - val_recall_10: 0.9837 - val_auc_10: 0.9982 - lr: 3.1250e-05
# Epoch 35/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0241 - accuracy: 0.9914 - precision_10: 0.9918 - recall_10: 0.9908 - auc_10: 0.9995
# Epoch 35: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 35: val_loss did not improve from 0.06106
# 1219/1219 [==============================] - 520s 426ms/step - loss: 0.0241 - accuracy: 0.9914 - precision_10: 0.9918 - recall_10: 0.9908 - auc_10: 0.9995 - val_loss: 0.0632 - val_accuracy: 0.9854 - val_precision_10: 0.9863 - val_recall_10: 0.9850 - val_auc_10: 0.9980 - lr: 3.1250e-05
# Epoch 36/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0239 - accuracy: 0.9912 - precision_10: 0.9916 - recall_10: 0.9905 - auc_10: 0.9995
# Epoch 36: val_loss did not improve from 0.06106
# 1219/1219 [==============================] - 535s 439ms/step - loss: 0.0239 - accuracy: 0.9912 - precision_10: 0.9916 - recall_10: 0.9905 - auc_10: 0.9995 - val_loss: 0.0635 - val_accuracy: 0.9854 - val_precision_10: 0.9864 - val_recall_10: 0.9850 - val_auc_10: 0.9980 - lr: 1.5625e-05
# Epoch 37/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0184 - accuracy: 0.9913 - precision_10: 0.9921 - recall_10: 0.9908 - auc_10: 0.9996
# Epoch 37: val_loss did not improve from 0.06106
# 1219/1219 [==============================] - 603s 494ms/step - loss: 0.0184 - accuracy: 0.9913 - precision_10: 0.9921 - recall_10: 0.9908 - auc_10: 0.9996 - val_loss: 0.0646 - val_accuracy: 0.9858 - val_precision_10: 0.9864 - val_recall_10: 0.9850 - val_auc_10: 0.9981 - lr: 1.5625e-05
# Epoch 38/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0194 - accuracy: 0.9925 - precision_10: 0.9930 - recall_10: 0.9920 - auc_10: 0.9995
# Epoch 38: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
#
# Epoch 38: val_loss did not improve from 0.06106
# 1219/1219 [==============================] - 528s 433ms/step - loss: 0.0194 - accuracy: 0.9925 - precision_10: 0.9930 - recall_10: 0.9920 - auc_10: 0.9995 - val_loss: 0.0653 - val_accuracy: 0.9857 - val_precision_10: 0.9865 - val_recall_10: 0.9851 - val_auc_10: 0.9981 - lr: 1.5625e-05
# Epoch 39/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0171 - accuracy: 0.9926 - precision_10: 0.9929 - recall_10: 0.9923 - auc_10: 0.9997
# Epoch 39: val_loss did not improve from 0.06106
# 1219/1219 [==============================] - 509s 418ms/step - loss: 0.0171 - accuracy: 0.9926 - precision_10: 0.9929 - recall_10: 0.9923 - auc_10: 0.9997 - val_loss: 0.0671 - val_accuracy: 0.9856 - val_precision_10: 0.9863 - val_recall_10: 0.9852 - val_auc_10: 0.9980 - lr: 7.8125e-06

# %%
# Print the keys of the training history
print(history_resnet_disease.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'precision_10', 'recall_10', 'auc_10', 'val_loss', 'val_accuracy', 'val_precision_10', 'val_recall_10', 'val_auc_10', 'lr'])

# %%
import matplotlib.pyplot as plt

# Plot Training vs Validation Loss
plt.figure(figsize=(12, 6))
plt.plot(history_resnet_disease.history['loss'], label='Training Loss')
plt.plot(history_resnet_disease.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training vs. Validation Loss')
plt.legend()
plt.grid()
plt.show()

# Plot Training vs Validation Accuracy
plt.figure(figsize=(12, 6))
plt.plot(history_resnet_disease.history['accuracy'], label='Training Accuracy')
plt.plot(history_resnet_disease.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training vs. Validation Accuracy')
plt.legend()
plt.grid()
plt.show()

# Plot Training vs Validation Precision
plt.figure(figsize=(12, 6))
plt.plot(history_resnet_disease.history['precision_10'], label='Training Precision')
plt.plot(history_resnet_disease.history['val_precision_10'], label='Validation Precision')
plt.xlabel('Epochs')
plt.ylabel('Precision')
plt.title('Training vs. Validation Precision')
plt.legend()
plt.grid()
plt.show()

# Plot Training vs Validation Recall
plt.figure(figsize=(12, 6))
plt.plot(history_resnet_disease.history['recall_10'], label='Training Recall')
plt.plot(history_resnet_disease.history['val_recall_10'], label='Validation Recall')
plt.xlabel('Epochs')
plt.ylabel('Recall')
plt.title('Training vs. Validation Recall')
plt.legend()
plt.grid()
plt.show()

# Plot Training vs Validation AUC
plt.figure(figsize=(12, 6))
plt.plot(history_resnet_disease.history['auc_10'], label='Training AUC')
plt.plot(history_resnet_disease.history['val_auc_10'], label='Validation AUC')
plt.xlabel('Epochs')
plt.ylabel('AUC')
plt.title('Training vs. Validation AUC')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### Densenet121

# %%
from tensorflow.keras.applications import DenseNet121  # Use a smaller model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from tensorflow.keras.metrics import Precision, Recall, AUC

# Load DenseNet121 with pre-trained ImageNet weights (using a smaller model)
base_model = DenseNet121(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the initial layers to reduce memory usage
for layer in base_model.layers[:300]:  # Freeze more layers to reduce computational load
    layer.trainable = False

# Custom layers on top of DenseNet121
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.4)(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.4)(x)
output = Dense(len(classes_list_disease), activation='softmax')(x)

# Define and compile the DenseNet121 model for disease classification
densenet_disease_model = Model(inputs=base_model.input, outputs=output)
densenet_disease_model.compile(optimizer=Adam(learning_rate=1e-3),
                               loss='categorical_crossentropy',
                               metrics=['accuracy', Precision(), Recall(), AUC()])

# Callbacks for DenseNet121 (Disease Classification)
checkpoint_densenet_disease = ModelCheckpoint(filepath=r'C:\Users\bheja\OneDrive\Desktop\models\densenet121_disease.h5', monitor='val_loss', save_best_only=True, verbose=1)
reduce_lr_disease = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-7, verbose=1)
early_stop_disease = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the DenseNet121 model with a reduced batch size
history_densenet_disease = densenet_disease_model.fit(
    train_generator_disease,
    epochs=50,
    validation_data=test_seen_generator_disease,
    #batch_size=8,  # Reduce the batch size if "Resource exhausted"
    class_weight=class_weights_disease_dict,
    callbacks=[reduce_lr_disease, early_stop_disease, checkpoint_densenet_disease]
)
# Out:
# Epoch 1/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.7182 - accuracy: 0.7970 - precision_11: 0.8533 - recall_11: 0.7596 - auc_11: 0.9777
# Epoch 1: val_loss improved from inf to 0.41235, saving model to C:\Users\bheja\OneDrive\Desktop\models\densenet121_disease.h5
# 1219/1219 [==============================] - 650s 521ms/step - loss: 0.7182 - accuracy: 0.7970 - precision_11: 0.8533 - recall_11: 0.7596 - auc_11: 0.9777 - val_loss: 0.4124 - val_accuracy: 0.9075 - val_precision_11: 0.9218 - val_recall_11: 0.8944 - val_auc_11: 0.9893 - lr: 0.0010
# Epoch 2/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.3109 - accuracy: 0.9039 - precision_11: 0.9249 - recall_11: 0.8852 - auc_11: 0.9917
# Epoch 2: val_loss improved from 0.41235 to 0.16726, saving model to C:\Users\bheja\OneDrive\Desktop\models\densenet121_disease.h5
# 1219/1219 [==============================] - 548s 449ms/step - loss: 0.3109 - accuracy: 0.9039 - precision_11: 0.9249 - recall_11: 0.8852 - auc_11: 0.9917 - val_loss: 0.1673 - val_accuracy: 0.9554 - val_precision_11: 0.9611 - val_recall_11: 0.9517 - val_auc_11: 0.9958 - lr: 0.0010
# Epoch 3/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.2413 - accuracy: 0.9292 - precision_11: 0.9428 - recall_11: 0.9162 - auc_11: 0.9934
# Epoch 3: val_loss did not improve from 0.16726
# 1219/1219 [==============================] - 544s 446ms/step - loss: 0.2413 - accuracy: 0.9292 - precision_11: 0.9428 - recall_11: 0.9162 - auc_11: 0.9934 - val_loss: 0.2200 - val_accuracy: 0.9469 - val_precision_11: 0.9512 - val_recall_11: 0.9427 - val_auc_11: 0.9936 - lr: 0.0010
# Epoch 4/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.2085 - accuracy: 0.9340 - precision_11: 0.9448 - recall_11: 0.9228 - auc_11: 0.9939
# Epoch 4: val_loss improved from 0.16726 to 0.10451, saving model to C:\Users\bheja\OneDrive\Desktop\models\densenet121_disease.h5
# 1219/1219 [==============================] - 549s 450ms/step - loss: 0.2085 - accuracy: 0.9340 - precision_11: 0.9448 - recall_11: 0.9228 - auc_11: 0.9939 - val_loss: 0.1045 - val_accuracy: 0.9706 - val_precision_11: 0.9746 - val_recall_11: 0.9682 - val_auc_11: 0.9976 - lr: 0.0010
# Epoch 5/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.1894 - accuracy: 0.9452 - precision_11: 0.9547 - recall_11: 0.9358 - auc_11: 0.9948
# Epoch 5: val_loss did not improve from 0.10451
# 1219/1219 [==============================] - 875s 718ms/step - loss: 0.1894 - accuracy: 0.9452 - precision_11: 0.9547 - recall_11: 0.9358 - auc_11: 0.9948 - val_loss: 0.2319 - val_accuracy: 0.9545 - val_precision_11: 0.9603 - val_recall_11: 0.9504 - val_auc_11: 0.9927 - lr: 0.0010
# Epoch 6/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.1766 - accuracy: 0.9494 - precision_11: 0.9580 - recall_11: 0.9402 - auc_11: 0.9951
# Epoch 6: val_loss did not improve from 0.10451
# 1219/1219 [==============================] - 923s 757ms/step - loss: 0.1766 - accuracy: 0.9494 - precision_11: 0.9580 - recall_11: 0.9402 - auc_11: 0.9951 - val_loss: 0.1803 - val_accuracy: 0.9572 - val_precision_11: 0.9628 - val_recall_11: 0.9534 - val_auc_11: 0.9943 - lr: 0.0010
# Epoch 7/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.1745 - accuracy: 0.9525 - precision_11: 0.9610 - recall_11: 0.9432 - auc_11: 0.9951
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 7: val_loss did not improve from 0.10451
# 1219/1219 [==============================] - 778s 638ms/step - loss: 0.1745 - accuracy: 0.9525 - precision_11: 0.9610 - recall_11: 0.9432 - auc_11: 0.9951 - val_loss: 0.1201 - val_accuracy: 0.9734 - val_precision_11: 0.9761 - val_recall_11: 0.9710 - val_auc_11: 0.9960 - lr: 0.0010
# Epoch 8/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0810 - accuracy: 0.9731 - precision_11: 0.9773 - recall_11: 0.9688 - auc_11: 0.9979
# Epoch 8: val_loss improved from 0.10451 to 0.08182, saving model to C:\Users\bheja\OneDrive\Desktop\models\densenet121_disease.h5
# 1219/1219 [==============================] - 772s 633ms/step - loss: 0.0810 - accuracy: 0.9731 - precision_11: 0.9773 - recall_11: 0.9688 - auc_11: 0.9979 - val_loss: 0.0818 - val_accuracy: 0.9778 - val_precision_11: 0.9786 - val_recall_11: 0.9766 - val_auc_11: 0.9979 - lr: 5.0000e-04
# Epoch 9/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0641 - accuracy: 0.9772 - precision_11: 0.9804 - recall_11: 0.9737 - auc_11: 0.9983
# Epoch 9: val_loss improved from 0.08182 to 0.06002, saving model to C:\Users\bheja\OneDrive\Desktop\models\densenet121_disease.h5
# 1219/1219 [==============================] - 702s 576ms/step - loss: 0.0641 - accuracy: 0.9772 - precision_11: 0.9804 - recall_11: 0.9737 - auc_11: 0.9983 - val_loss: 0.0600 - val_accuracy: 0.9844 - val_precision_11: 0.9855 - val_recall_11: 0.9838 - val_auc_11: 0.9981 - lr: 5.0000e-04
# Epoch 10/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0562 - accuracy: 0.9804 - precision_11: 0.9833 - recall_11: 0.9781 - auc_11: 0.9985
# Epoch 10: val_loss did not improve from 0.06002
# 1219/1219 [==============================] - 543s 445ms/step - loss: 0.0562 - accuracy: 0.9804 - precision_11: 0.9833 - recall_11: 0.9781 - auc_11: 0.9985 - val_loss: 0.0676 - val_accuracy: 0.9842 - val_precision_11: 0.9856 - val_recall_11: 0.9835 - val_auc_11: 0.9979 - lr: 5.0000e-04
# Epoch 11/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0660 - accuracy: 0.9794 - precision_11: 0.9817 - recall_11: 0.9770 - auc_11: 0.9981
# Epoch 11: val_loss did not improve from 0.06002
# 1219/1219 [==============================] - 551s 452ms/step - loss: 0.0660 - accuracy: 0.9794 - precision_11: 0.9817 - recall_11: 0.9770 - auc_11: 0.9981 - val_loss: 0.0663 - val_accuracy: 0.9817 - val_precision_11: 0.9832 - val_recall_11: 0.9806 - val_auc_11: 0.9988 - lr: 5.0000e-04
# Epoch 12/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0584 - accuracy: 0.9815 - precision_11: 0.9837 - recall_11: 0.9794 - auc_11: 0.9983
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 12: val_loss did not improve from 0.06002
# 1219/1219 [==============================] - 549s 450ms/step - loss: 0.0584 - accuracy: 0.9815 - precision_11: 0.9837 - recall_11: 0.9794 - auc_11: 0.9983 - val_loss: 0.1162 - val_accuracy: 0.9738 - val_precision_11: 0.9774 - val_recall_11: 0.9712 - val_auc_11: 0.9969 - lr: 5.0000e-04
# Epoch 13/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0379 - accuracy: 0.9872 - precision_11: 0.9888 - recall_11: 0.9858 - auc_11: 0.9990
# Epoch 13: val_loss improved from 0.06002 to 0.04011, saving model to C:\Users\bheja\OneDrive\Desktop\models\densenet121_disease.h5
# 1219/1219 [==============================] - 546s 448ms/step - loss: 0.0379 - accuracy: 0.9872 - precision_11: 0.9888 - recall_11: 0.9858 - auc_11: 0.9990 - val_loss: 0.0401 - val_accuracy: 0.9895 - val_precision_11: 0.9904 - val_recall_11: 0.9889 - val_auc_11: 0.9990 - lr: 2.5000e-04
# Epoch 14/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0366 - accuracy: 0.9902 - precision_11: 0.9912 - recall_11: 0.9888 - auc_11: 0.9994
# Epoch 14: val_loss did not improve from 0.04011
# 1219/1219 [==============================] - 549s 450ms/step - loss: 0.0366 - accuracy: 0.9902 - precision_11: 0.9912 - recall_11: 0.9888 - auc_11: 0.9994 - val_loss: 0.0410 - val_accuracy: 0.9894 - val_precision_11: 0.9905 - val_recall_11: 0.9892 - val_auc_11: 0.9990 - lr: 2.5000e-04
# Epoch 15/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0286 - accuracy: 0.9894 - precision_11: 0.9904 - recall_11: 0.9882 - auc_11: 0.9991
# Epoch 15: val_loss improved from 0.04011 to 0.03955, saving model to C:\Users\bheja\OneDrive\Desktop\models\densenet121_disease.h5
# 1219/1219 [==============================] - 551s 452ms/step - loss: 0.0286 - accuracy: 0.9894 - precision_11: 0.9904 - recall_11: 0.9882 - auc_11: 0.9991 - val_loss: 0.0396 - val_accuracy: 0.9910 - val_precision_11: 0.9916 - val_recall_11: 0.9906 - val_auc_11: 0.9989 - lr: 2.5000e-04
# Epoch 16/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0271 - accuracy: 0.9915 - precision_11: 0.9925 - recall_11: 0.9906 - auc_11: 0.9994
# Epoch 16: val_loss did not improve from 0.03955
# 1219/1219 [==============================] - 553s 454ms/step - loss: 0.0271 - accuracy: 0.9915 - precision_11: 0.9925 - recall_11: 0.9906 - auc_11: 0.9994 - val_loss: 0.0509 - val_accuracy: 0.9880 - val_precision_11: 0.9885 - val_recall_11: 0.9879 - val_auc_11: 0.9984 - lr: 2.5000e-04
# Epoch 17/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0264 - accuracy: 0.9908 - precision_11: 0.9916 - recall_11: 0.9899 - auc_11: 0.9993
# Epoch 17: val_loss did not improve from 0.03955
# 1219/1219 [==============================] - 554s 455ms/step - loss: 0.0264 - accuracy: 0.9908 - precision_11: 0.9916 - recall_11: 0.9899 - auc_11: 0.9993 - val_loss: 0.0449 - val_accuracy: 0.9906 - val_precision_11: 0.9913 - val_recall_11: 0.9901 - val_auc_11: 0.9986 - lr: 2.5000e-04
# Epoch 18/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0278 - accuracy: 0.9912 - precision_11: 0.9922 - recall_11: 0.9906 - auc_11: 0.9994
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 18: val_loss did not improve from 0.03955
# 1219/1219 [==============================] - 724s 594ms/step - loss: 0.0278 - accuracy: 0.9912 - precision_11: 0.9922 - recall_11: 0.9906 - auc_11: 0.9994 - val_loss: 0.0492 - val_accuracy: 0.9886 - val_precision_11: 0.9891 - val_recall_11: 0.9881 - val_auc_11: 0.9987 - lr: 2.5000e-04
# Epoch 19/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0147 - accuracy: 0.9945 - precision_11: 0.9950 - recall_11: 0.9940 - auc_11: 0.9996
# Epoch 19: val_loss did not improve from 0.03955
# 1219/1219 [==============================] - 791s 649ms/step - loss: 0.0147 - accuracy: 0.9945 - precision_11: 0.9950 - recall_11: 0.9940 - auc_11: 0.9996 - val_loss: 0.0403 - val_accuracy: 0.9906 - val_precision_11: 0.9908 - val_recall_11: 0.9903 - val_auc_11: 0.9988 - lr: 1.2500e-04
# Epoch 20/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0166 - accuracy: 0.9943 - precision_11: 0.9948 - recall_11: 0.9937 - auc_11: 0.9996
# Epoch 20: val_loss did not improve from 0.03955
# 1219/1219 [==============================] - 883s 724ms/step - loss: 0.0166 - accuracy: 0.9943 - precision_11: 0.9948 - recall_11: 0.9937 - auc_11: 0.9996 - val_loss: 0.0416 - val_accuracy: 0.9909 - val_precision_11: 0.9913 - val_recall_11: 0.9902 - val_auc_11: 0.9989 - lr: 1.2500e-04
# Epoch 21/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0148 - accuracy: 0.9950 - precision_11: 0.9954 - recall_11: 0.9947 - auc_11: 0.9995
# Epoch 21: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 21: val_loss did not improve from 0.03955
# 1219/1219 [==============================] - 781s 641ms/step - loss: 0.0148 - accuracy: 0.9950 - precision_11: 0.9954 - recall_11: 0.9947 - auc_11: 0.9995 - val_loss: 0.0475 - val_accuracy: 0.9892 - val_precision_11: 0.9895 - val_recall_11: 0.9889 - val_auc_11: 0.9990 - lr: 1.2500e-04
# Epoch 22/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0149 - accuracy: 0.9949 - precision_11: 0.9955 - recall_11: 0.9945 - auc_11: 0.9998
# Epoch 22: val_loss did not improve from 0.03955
# 1219/1219 [==============================] - 561s 460ms/step - loss: 0.0149 - accuracy: 0.9949 - precision_11: 0.9955 - recall_11: 0.9945 - auc_11: 0.9998 - val_loss: 0.0402 - val_accuracy: 0.9904 - val_precision_11: 0.9908 - val_recall_11: 0.9901 - val_auc_11: 0.9991 - lr: 6.2500e-05
# Epoch 23/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0101 - accuracy: 0.9959 - precision_11: 0.9962 - recall_11: 0.9955 - auc_11: 0.9997
# Epoch 23: val_loss improved from 0.03955 to 0.03798, saving model to C:\Users\bheja\OneDrive\Desktop\models\densenet121_disease.h5
# 1219/1219 [==============================] - 562s 461ms/step - loss: 0.0101 - accuracy: 0.9959 - precision_11: 0.9962 - recall_11: 0.9955 - auc_11: 0.9997 - val_loss: 0.0380 - val_accuracy: 0.9910 - val_precision_11: 0.9914 - val_recall_11: 0.9909 - val_auc_11: 0.9989 - lr: 6.2500e-05
# Epoch 24/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0094 - accuracy: 0.9963 - precision_11: 0.9966 - recall_11: 0.9958 - auc_11: 0.9998
# Epoch 24: val_loss improved from 0.03798 to 0.03447, saving model to C:\Users\bheja\OneDrive\Desktop\models\densenet121_disease.h5
# 1219/1219 [==============================] - 558s 458ms/step - loss: 0.0094 - accuracy: 0.9963 - precision_11: 0.9966 - recall_11: 0.9958 - auc_11: 0.9998 - val_loss: 0.0345 - val_accuracy: 0.9919 - val_precision_11: 0.9925 - val_recall_11: 0.9917 - val_auc_11: 0.9990 - lr: 6.2500e-05
# Epoch 25/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0108 - accuracy: 0.9964 - precision_11: 0.9966 - recall_11: 0.9962 - auc_11: 0.9998
# Epoch 25: val_loss did not improve from 0.03447
# 1219/1219 [==============================] - 575s 472ms/step - loss: 0.0108 - accuracy: 0.9964 - precision_11: 0.9966 - recall_11: 0.9962 - auc_11: 0.9998 - val_loss: 0.0354 - val_accuracy: 0.9929 - val_precision_11: 0.9933 - val_recall_11: 0.9926 - val_auc_11: 0.9990 - lr: 6.2500e-05
# Epoch 26/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0090 - accuracy: 0.9969 - precision_11: 0.9972 - recall_11: 0.9966 - auc_11: 0.9998
# Epoch 26: val_loss did not improve from 0.03447
# 1219/1219 [==============================] - 923s 757ms/step - loss: 0.0090 - accuracy: 0.9969 - precision_11: 0.9972 - recall_11: 0.9966 - auc_11: 0.9998 - val_loss: 0.0355 - val_accuracy: 0.9926 - val_precision_11: 0.9933 - val_recall_11: 0.9925 - val_auc_11: 0.9990 - lr: 6.2500e-05
# Epoch 27/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0084 - accuracy: 0.9968 - precision_11: 0.9971 - recall_11: 0.9965 - auc_11: 0.9997
# Epoch 27: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 27: val_loss did not improve from 0.03447
# 1219/1219 [==============================] - 779s 639ms/step - loss: 0.0084 - accuracy: 0.9968 - precision_11: 0.9971 - recall_11: 0.9965 - auc_11: 0.9997 - val_loss: 0.0386 - val_accuracy: 0.9917 - val_precision_11: 0.9921 - val_recall_11: 0.9914 - val_auc_11: 0.9989 - lr: 6.2500e-05
# Epoch 28/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0064 - accuracy: 0.9975 - precision_11: 0.9977 - recall_11: 0.9973 - auc_11: 0.9999
# Epoch 28: val_loss did not improve from 0.03447
# 1219/1219 [==============================] - 556s 456ms/step - loss: 0.0064 - accuracy: 0.9975 - precision_11: 0.9977 - recall_11: 0.9973 - auc_11: 0.9999 - val_loss: 0.0399 - val_accuracy: 0.9920 - val_precision_11: 0.9925 - val_recall_11: 0.9919 - val_auc_11: 0.9987 - lr: 3.1250e-05
# Epoch 29/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0065 - accuracy: 0.9978 - precision_11: 0.9980 - recall_11: 0.9975 - auc_11: 0.9999
# Epoch 29: val_loss did not improve from 0.03447
# 1219/1219 [==============================] - 766s 629ms/step - loss: 0.0065 - accuracy: 0.9978 - precision_11: 0.9980 - recall_11: 0.9975 - auc_11: 0.9999 - val_loss: 0.0354 - val_accuracy: 0.9929 - val_precision_11: 0.9932 - val_recall_11: 0.9927 - val_auc_11: 0.9987 - lr: 3.1250e-05
# Epoch 30/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0066 - accuracy: 0.9972 - precision_11: 0.9974 - recall_11: 0.9970 - auc_11: 0.9999
# Epoch 30: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 30: val_loss did not improve from 0.03447
# 1219/1219 [==============================] - 988s 811ms/step - loss: 0.0066 - accuracy: 0.9972 - precision_11: 0.9974 - recall_11: 0.9970 - auc_11: 0.9999 - val_loss: 0.0352 - val_accuracy: 0.9933 - val_precision_11: 0.9939 - val_recall_11: 0.9932 - val_auc_11: 0.9989 - lr: 3.1250e-05
# Epoch 31/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0082 - accuracy: 0.9976 - precision_11: 0.9979 - recall_11: 0.9974 - auc_11: 0.9998
# Epoch 31: val_loss did not improve from 0.03447
# 1219/1219 [==============================] - 901s 739ms/step - loss: 0.0082 - accuracy: 0.9976 - precision_11: 0.9979 - recall_11: 0.9974 - auc_11: 0.9998 - val_loss: 0.0352 - val_accuracy: 0.9929 - val_precision_11: 0.9933 - val_recall_11: 0.9927 - val_auc_11: 0.9989 - lr: 1.5625e-05
# Epoch 32/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0058 - accuracy: 0.9977 - precision_11: 0.9979 - recall_11: 0.9976 - auc_11: 0.9999
# Epoch 32: val_loss did not improve from 0.03447
# 1219/1219 [==============================] - 610s 501ms/step - loss: 0.0058 - accuracy: 0.9977 - precision_11: 0.9979 - recall_11: 0.9976 - auc_11: 0.9999 - val_loss: 0.0363 - val_accuracy: 0.9932 - val_precision_11: 0.9934 - val_recall_11: 0.9929 - val_auc_11: 0.9989 - lr: 1.5625e-05
# Epoch 33/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0044 - accuracy: 0.9980 - precision_11: 0.9982 - recall_11: 0.9979 - auc_11: 0.9999
# Epoch 33: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
#
# Epoch 33: val_loss did not improve from 0.03447
# 1219/1219 [==============================] - 560s 459ms/step - loss: 0.0044 - accuracy: 0.9980 - precision_11: 0.9982 - recall_11: 0.9979 - auc_11: 0.9999 - val_loss: 0.0375 - val_accuracy: 0.9932 - val_precision_11: 0.9935 - val_recall_11: 0.9930 - val_auc_11: 0.9988 - lr: 1.5625e-05
# Epoch 34/50
# 1219/1219 [==============================] - ETA: 0s - loss: 0.0052 - accuracy: 0.9983 - precision_11: 0.9983 - recall_11: 0.9981 - auc_11: 0.9999
# Epoch 34: val_loss did not improve from 0.03447
# 1219/1219 [==============================] - 550s 451ms/step - loss: 0.0052 - accuracy: 0.9983 - precision_11: 0.9983 - recall_11: 0.9981 - auc_11: 0.9999 - val_loss: 0.0373 - val_accuracy: 0.9927 - val_precision_11: 0.9930 - val_recall_11: 0.9925 - val_auc_11: 0.9989 - lr: 7.8125e-06

# %%
import matplotlib.pyplot as plt

# Plot Training vs Validation Loss
plt.figure(figsize=(12, 6))
plt.plot(history_densenet_disease.history['loss'], label='Training Loss')
plt.plot(history_densenet_disease.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training vs. Validation Loss')
plt.legend()
plt.grid()
plt.show()

# Plot Training vs Validation Accuracy
plt.figure(figsize=(12, 6))
plt.plot(history_densenet_disease.history['accuracy'], label='Training Accuracy')
plt.plot(history_densenet_disease.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training vs. Validation Accuracy')
plt.legend()
plt.grid()
plt.show()

# Plot Training vs Validation Precision
plt.figure(figsize=(12, 6))
plt.plot(history_densenet_disease.history['precision_11'], label='Training Precision')
plt.plot(history_densenet_disease.history['val_precision_11'], label='Validation Precision')
plt.xlabel('Epochs')
plt.ylabel('Precision')
plt.title('Training vs. Validation Precision')
plt.legend()
plt.grid()
plt.show()

# Plot Training vs Validation Recall
plt.figure(figsize=(12, 6))
plt.plot(history_densenet_disease.history['recall_11'], label='Training Recall')
plt.plot(history_densenet_disease.history['val_recall_11'], label='Validation Recall')
plt.xlabel('Epochs')
plt.ylabel('Recall')
plt.title('Training vs. Validation Recall')
plt.legend()
plt.grid()
plt.show()

# Plot Training vs Validation AUC
plt.figure(figsize=(12, 6))
plt.plot(history_densenet_disease.history['auc_11'], label='Training AUC')
plt.plot(history_densenet_disease.history['val_auc_11'], label='Validation AUC')
plt.xlabel('Epochs')
plt.ylabel('AUC')
plt.title('Training vs. Validation AUC')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### EfficientNet ---- Did not run (Resource exhausted) -- laptop gpu rtx 3050

# %%
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from tensorflow.keras.metrics import Precision, Recall, AUC

# Load EfficientNetB0 with pre-trained ImageNet weights for disease classification
base_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Custom layers on top of EfficientNetB0 for disease classification
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.4)(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.4)(x)
output = Dense(len(classes_list_disease), activation='softmax')(x)  # Updated to use classes_list_disease

# Define and compile the EfficientNetB0 model for disease classification
efficientnet_model_disease = Model(inputs=base_model.input, outputs=output)
efficientnet_model_disease.compile(optimizer=Adam(learning_rate=1e-3),
                                   loss='categorical_crossentropy',
                                   metrics=['accuracy', Precision(), Recall(), AUC()])

# Callbacks for EfficientNetB0 disease model
checkpoint_efficientnet_disease = ModelCheckpoint(filepath=r'C:\Users\bheja\OneDrive\Desktop\models\efficientb0_disease.h5', monitor='val_loss', save_best_only=True, verbose=1)
reduce_lr_disease = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-7, verbose=1)
early_stop_disease = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the EfficientNetB0 model for disease classification
history_efficientnet_disease = efficientnet_model_disease.fit(
    train_generator_disease,
    epochs=50,
    validation_data=test_seen_generator_disease,
    class_weight=class_weights_disease_dict,
    callbacks=[reduce_lr_disease, early_stop_disease, checkpoint_efficientnet_disease]
)
